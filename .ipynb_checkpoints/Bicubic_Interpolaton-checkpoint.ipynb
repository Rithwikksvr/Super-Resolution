# %%
import numpy as np
import cv2
import numpy
import math
import os
import sklearn.linear_model
import sklearn.datasets
import matplotlib.pyplot as plt
import autograd.numpy as np
from autograd import grad
import time
import threading
#from Data_File import Data
import Data_File
plt.close('all')

# %%
train_x,train_y = Data_File.Data('faces')
test_x,test_y = Data_File.Data('test')

(h,w) = train_y[0].shape

A = np.random.random((h,h//2))/10
B = np.random.random((w//2,w))/10

# %%
def psnr(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

def mse(img1,img2):
    return np.mean(np.square(img1 - img2))

def cost(A,B,X,y):
    total_error = 0
    ans = np.random.random((len(X),1))
    index=0
    arr = []
    for i in range(len(X)):
        
        pred = np.matmul(np.matmul(A,X[i]),B)
        total_error = total_error + mse(pred,y[i])
        index+=1
        arr.append(mse(pred,y[i]))
        total_error+=mse(pred ,y)
        
    return sum(arr)/len(arr)


def pred(img,results):
    
    ans[index,:,:] = x2
    return x2


def cost2(A,B,X,y):
    total_error = 0
    ans = np.random.random((len(X),1))
    index=0
    objs=[]
    for i in range(1):
        thd_obj = threading.Thread(target=pred_and_cost, args=(A,B,X[i],y[i],ans,index,))
        thd_obj.start()
        objs.append(thd_obj)
        
        index+=1
        
        
    for i in objs:
        i.join()
            
    return (ans.sum()/len(ans))


def pred_and_cost(A,B,img,y,results,index):
    
    x1 = np.matmul(A,img)
    x2 = np.matmul(x1,B)
    print (index,mse(x2,y))
    results[index] = mse(x2,y)
    #print ("Image "+str(index) + ' is done')

# %%
train_x[0]
# Out:
# array([[ 0.03529412,  0.01568627,  0.01176471, ...,  0.42745098,
#          0.42745098,  0.41176471],
#        [ 0.05098039,  0.01960784,  0.01176471, ...,  0.43529412,
#          0.41568627,  0.41176471],
#        [ 0.04705882,  0.01960784,  0.01568627, ...,  0.15686275,
#          0.03921569,  0.11764706],
#        ...,
#        [ 0.42745098,  0.40392157,  0.2627451 , ...,  0.55294118,
#          0.4745098 ,  0.4745098 ],
#        [ 0.49411765,  0.03529412,  0.21568627, ...,  0.4       ,
#          0.40784314,  0.40392157],
#        [ 0.10588235,  0.03529412,  0.2       , ...,  0.39607843,
#          0.40392157,  0.4       ]])

# %%
trainer = grad(cost2,argnum=[0,1])
alpha = .001
iterations = 60

# %%
for i in range(iterations):
    grad_A,grad_B = trainer(A,B,train_x,train_y)
    
    A -=alpha*grad_A
    B -=alpha*grad_B
    if i%10==0:
        print (cost(A,B,train_x,train_y))
# Out:
# Exception in thread Thread-12505:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12506:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12507:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12508:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12509:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12510:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12513:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12511:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12514:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12515:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12516:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12517:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12518:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12519:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12520:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12521:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12522:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12523:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12524:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12525:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12526:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12527:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12528:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12512:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12529:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12530:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12531:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12532:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12533:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12534:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12535:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12536:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12537:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12538:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12539:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12540:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12541:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12542:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12543:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12544:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12545:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12546:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12547:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12548:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12549:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12550:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12551:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12552:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12553:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12554:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12555:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12556:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12557:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12558:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12559:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12560:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12561:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12562:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12563:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12564:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12565:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12566:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12567:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12568:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12569:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12570:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12571:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12572:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12573:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12574:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12575:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12576:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12577:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12578:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12579:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12580:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12581:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12582:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12583:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12584:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12585:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12586:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12587:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12588:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12589:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12590:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12591:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12592:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12593:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12594:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12595:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12596:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12597:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12598:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12599:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12600:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12601:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12602:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12603:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12604:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
# 0.464788494677
# Exception in thread Thread-12605:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12606:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12608:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12607:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12609:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-12610:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
# ...
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18470:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18471:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18472:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18473:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18474:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18475:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18476:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18477:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18478:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18479:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18480:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18481:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18482:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18483:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18484:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18485:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18486:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18487:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18488:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18489:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18490:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18491:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18492:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18493:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18494:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18495:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18496:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18497:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18498:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18499:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18500:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18501:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18502:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18503:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.
#
# Exception in thread Thread-18504:
# Traceback (most recent call last):
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 801, in __bootstrap_inner
#     self.run()
#   File "/home/rithwik/anaconda/lib/python2.7/threading.py", line 754, in run
#     self.__target(*self.__args, **self.__kwargs)
#   File "<ipython-input-29-b3ee588a5c0d>", line 55, in pred_and_cost
#     results[index] = mse(x2,y)
# ValueError: setting an array element with a sequence.

# %%
cost(A,B,train_x,train_y)
# Out:
# 3.3077394791935375

# %%
cost2(A,B,train_x,train_y)
# Out:
# 3.3077394791935366

# %%
cost(A,B,train_x,train_y)
# Out:
# 4.5949260842879314
