# %%
import numpy as np
import cv2
import numpy
import math
import os
import sklearn.linear_model
import sklearn.datasets
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
plt.close('all')

# %%
def psnr(img1, img2):
    mse = numpy.mean( (img1 - img2) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    return 20 * math.log10(PIXEL_MAX / math.sqrt(mse))

# %%
test_error = []
train_error = []
x_axis = []

for k in range(2,50):    
    folder = 'faces'
    lst = os.listdir(folder)
    imgs_hr = []
    
    for i in lst:
        img = cv2.imread(folder+"/"+i,0)
        img = cv2.resize(img,(0,0), fx=0.25, fy=0.25)
        imgs_hr.append(img)
        
    imgs_hr = np.array(imgs_hr)
    imgs_hr = imgs_hr.astype(float)
    imgs_lr = imgs_hr[:,::2,::2]
    
    h,w = imgs_hr[0].shape
    
    y = imgs_hr.reshape((len(imgs_hr),w*h))/255
    X = imgs_lr.reshape((len(imgs_lr),int(h*w*.25)))/255
    imgs_hr = None
    imgs_lr = None
    
    model = KNeighborsRegressor(n_neighbors=k,weights='distance')
    
    print ("Started training Model ",k)
    model.fit(X,y)
    
    Train_error = np.mean(np.square(y - model.predict(X)))/len(y)
    print ("Training  Error with k = "+ str(k)+"  is ",Train_error)
    
    s = 0
    pred1 = model.predict(X)
    for i in range(len(pred1)):
        s = s + psnr(y[i]*255,pred1[i]*255)
    s = s/(i+1)
    print ("Average training PSNR : with K = "+str( k) + ' is '+str( s))
    
    
    #######Test Data####
    
    
    folder = 'test'
    lst = os.listdir(folder)
    imgs_hr = []
    for i in lst:
        img = cv2.imread(folder+"/"+i,0)
        img = cv2.resize(img,(0,0), fx=0.25, fy=0.25)
        imgs_hr.append(img)
        
    imgs_hr = np.array(imgs_hr)
    imgs_hr = imgs_hr.astype(float)
    imgs_lr = imgs_hr[:,::2,::2]
    
    y = imgs_hr.reshape((len(imgs_hr),w*h))/255
    X = imgs_lr.reshape((len(imgs_lr),int(h*w*.25)))/255
    
    imgs_hr=None
    imgs_lr = None
    
    img_id=0
    pred = model.predict(X[:,:])
    
    test = np.mean(np.square(y - model.predict(X)))
    print ("Testing Error with k = "+ str(k)+"  is ",test)
    
    s = 0
    pred1 = model.predict(X)
    
    for i in range(len(pred1)):
        s = s + psnr(y[i]*255,pred1[i]*255)
    s = s/len(y)
    print ("Average Testing PSNR : with K = "+ str(k) + ' is '+ str(s))
    
    reshaped = pred.reshape((len(pred),h,w))
    y = y.reshape((len(X),h,w))
    
    model = None
    neight = None
    
    test_error.append(test)
    
    x_axis.append(k)
# Out:
# ('Started training Model ', 2)
# ('Training  Error with k = 2  is ', 0.0)
# Average training PSNR : with K = 2 is 100
# ('Testing Error with k = 2  is ', 0.042531296478559341)
# Average Testing PSNR : with K = 2 is 13.8736920638
# ('Started training Model ', 3)
# ('Training  Error with k = 3  is ', 0.0)
# Average training PSNR : with K = 3 is 100
# ('Testing Error with k = 3  is ', 0.040033617707948901)
# Average Testing PSNR : with K = 3 is 14.1586631303
# ('Started training Model ', 4)
# ('Training  Error with k = 4  is ', 0.0)
# Average training PSNR : with K = 4 is 100
# ('Testing Error with k = 4  is ', 0.038699435671813075)
# Average Testing PSNR : with K = 4 is 14.3123254341
# ('Started training Model ', 5)
# ('Training  Error with k = 5  is ', 0.0)
# Average training PSNR : with K = 5 is 100
# ('Testing Error with k = 5  is ', 0.038195836616273758)
# Average Testing PSNR : with K = 5 is 14.365912308
# ('Started training Model ', 6)
# ('Training  Error with k = 6  is ', 0.0)
# Average training PSNR : with K = 6 is 100
# ('Testing Error with k = 6  is ', 0.037736358965430747)
# Average Testing PSNR : with K = 6 is 14.4266619496
# ('Started training Model ', 7)
# ('Training  Error with k = 7  is ', 0.0)
# Average training PSNR : with K = 7 is 100
# ('Testing Error with k = 7  is ', 0.037581308667580395)
# Average Testing PSNR : with K = 7 is 14.4380891133
# ('Started training Model ', 8)
# ('Training  Error with k = 8  is ', 0.0)
# Average training PSNR : with K = 8 is 100
# ('Testing Error with k = 8  is ', 0.037507778580105407)
# Average Testing PSNR : with K = 8 is 14.445764634
# ('Started training Model ', 9)
# ('Training  Error with k = 9  is ', 0.0)
# Average training PSNR : with K = 9 is 100
# ('Testing Error with k = 9  is ', 0.037757939330650234)
# Average Testing PSNR : with K = 9 is 14.4168546563
# ('Started training Model ', 10)
# ('Training  Error with k = 10  is ', 0.0)
# Average training PSNR : with K = 10 is 100
# ('Testing Error with k = 10  is ', 0.037673670551640413)
# Average Testing PSNR : with K = 10 is 14.4300858935
# ('Started training Model ', 11)
# ('Training  Error with k = 11  is ', 0.0)
# Average training PSNR : with K = 11 is 100
# ('Testing Error with k = 11  is ', 0.037801951387827624)
# Average Testing PSNR : with K = 11 is 14.4175347161
# ('Started training Model ', 12)
# ('Training  Error with k = 12  is ', 0.0)
# Average training PSNR : with K = 12 is 100
# ('Testing Error with k = 12  is ', 0.037942376823118247)
# Average Testing PSNR : with K = 12 is 14.3960311683
# ('Started training Model ', 13)
# ('Training  Error with k = 13  is ', 0.0)
# Average training PSNR : with K = 13 is 100
# ('Testing Error with k = 13  is ', 0.038062940303061274)
# Average Testing PSNR : with K = 13 is 14.38750939
# ('Started training Model ', 14)
# ('Training  Error with k = 14  is ', 0.0)
# Average training PSNR : with K = 14 is 100
# ('Testing Error with k = 14  is ', 0.038198203293919659)
# Average Testing PSNR : with K = 14 is 14.3782181456
# ('Started training Model ', 15)
# ('Training  Error with k = 15  is ', 0.0)
# Average training PSNR : with K = 15 is 100
# ('Testing Error with k = 15  is ', 0.038397618815270179)
# Average Testing PSNR : with K = 15 is 14.3565972074
# ('Started training Model ', 16)
# ('Training  Error with k = 16  is ', 0.0)
# Average training PSNR : with K = 16 is 100
# ('Testing Error with k = 16  is ', 0.038636461183469029)
# Average Testing PSNR : with K = 16 is 14.3310823015
# ('Started training Model ', 17)
# ('Training  Error with k = 17  is ', 0.0)
# Average training PSNR : with K = 17 is 100
# ('Testing Error with k = 17  is ', 0.038855368265395984)
# Average Testing PSNR : with K = 17 is 14.3098485584
# ('Started training Model ', 18)
# ('Training  Error with k = 18  is ', 0.0)
# Average training PSNR : with K = 18 is 100
# ('Testing Error with k = 18  is ', 0.038950549387565238)
# Average Testing PSNR : with K = 18 is 14.3045411329
# ('Started training Model ', 19)
# ('Training  Error with k = 19  is ', 0.0)
# Average training PSNR : with K = 19 is 100
# ('Testing Error with k = 19  is ', 0.03910875232287829)
# Average Testing PSNR : with K = 19 is 14.2873915109
# ('Started training Model ', 20)
# ('Training  Error with k = 20  is ', 0.0)
# Average training PSNR : with K = 20 is 100
# ('Testing Error with k = 20  is ', 0.039271688684926385)
# Average Testing PSNR : with K = 20 is 14.2686584628
# ('Started training Model ', 21)
# ('Training  Error with k = 21  is ', 0.0)
# Average training PSNR : with K = 21 is 100
# ('Testing Error with k = 21  is ', 0.039434940249633614)
# Average Testing PSNR : with K = 21 is 14.2490982996
# ('Started training Model ', 22)
# ('Training  Error with k = 22  is ', 0.0)
# Average training PSNR : with K = 22 is 100
# ('Testing Error with k = 22  is ', 0.039583000396903101)
# Average Testing PSNR : with K = 22 is 14.2314570467
# ('Started training Model ', 23)
# ('Training  Error with k = 23  is ', 0.0)
# Average training PSNR : with K = 23 is 100
# ('Testing Error with k = 23  is ', 0.039770126970024744)
# Average Testing PSNR : with K = 23 is 14.2117052222
# ('Started training Model ', 24)
# ('Training  Error with k = 24  is ', 0.0)
# Average training PSNR : with K = 24 is 100
# ('Testing Error with k = 24  is ', 0.039929783077640987)
# Average Testing PSNR : with K = 24 is 14.1956339371
# ('Started training Model ', 25)
# ('Training  Error with k = 25  is ', 0.0)
# Average training PSNR : with K = 25 is 100
# ('Testing Error with k = 25  is ', 0.040037038212994605)
# Average Testing PSNR : with K = 25 is 14.1853076811
# ('Started training Model ', 26)
# ('Training  Error with k = 26  is ', 0.0)
# Average training PSNR : with K = 26 is 100
# ('Testing Error with k = 26  is ', 0.040196569522554168)
# Average Testing PSNR : with K = 26 is 14.1708220725
# ('Started training Model ', 27)
# ('Training  Error with k = 27  is ', 0.0)
# Average training PSNR : with K = 27 is 100
# ('Testing Error with k = 27  is ', 0.040400506419031819)
# Average Testing PSNR : with K = 27 is 14.15011319
# ('Started training Model ', 28)
# ('Training  Error with k = 28  is ', 0.0)
# Average training PSNR : with K = 28 is 100
# ('Testing Error with k = 28  is ', 0.040523280707640316)
# Average Testing PSNR : with K = 28 is 14.1371305633
# ('Started training Model ', 29)
# ('Training  Error with k = 29  is ', 0.0)
# Average training PSNR : with K = 29 is 100
# ('Testing Error with k = 29  is ', 0.040662762969433344)
# Average Testing PSNR : with K = 29 is 14.1229776612
# ('Started training Model ', 30)
# ('Training  Error with k = 30  is ', 0.0)
# Average training PSNR : with K = 30 is 100
# ('Testing Error with k = 30  is ', 0.040857685094688623)
# Average Testing PSNR : with K = 30 is 14.1006495526
# ('Started training Model ', 31)
# ('Training  Error with k = 31  is ', 0.0)
# Average training PSNR : with K = 31 is 100
# ('Testing Error with k = 31  is ', 0.041094241200242076)
# Average Testing PSNR : with K = 31 is 14.0768728432
# ('Started training Model ', 32)
# ('Training  Error with k = 32  is ', 0.0)
# Average training PSNR : with K = 32 is 100
# ('Testing Error with k = 32  is ', 0.041280333139986594)
# Average Testing PSNR : with K = 32 is 14.057444953
# ('Started training Model ', 33)
# ('Training  Error with k = 33  is ', 0.0)
# Average training PSNR : with K = 33 is 100
# ('Testing Error with k = 33  is ', 0.041475872281784384)
# Average Testing PSNR : with K = 33 is 14.0371331979
# ('Started training Model ', 34)
# ('Training  Error with k = 34  is ', 0.0)
# Average training PSNR : with K = 34 is 100
# ('Testing Error with k = 34  is ', 0.041670482101937217)
# Average Testing PSNR : with K = 34 is 14.0171544181
# ('Started training Model ', 35)
# ('Training  Error with k = 35  is ', 0.0)
# Average training PSNR : with K = 35 is 100
# ('Testing Error with k = 35  is ', 0.041761289659594754)
# Average Testing PSNR : with K = 35 is 14.0089995846
# ('Started training Model ', 36)
# ('Training  Error with k = 36  is ', 0.0)
# Average training PSNR : with K = 36 is 100
# ('Testing Error with k = 36  is ', 0.041850308999317923)
# Average Testing PSNR : with K = 36 is 13.9988455892
# ('Started training Model ', 37)
# ('Training  Error with k = 37  is ', 0.0)
# Average training PSNR : with K = 37 is 100
# ('Testing Error with k = 37  is ', 0.042014966742187465)
# Average Testing PSNR : with K = 37 is 13.9814022681
# ('Started training Model ', 38)
# ('Training  Error with k = 38  is ', 0.0)
# Average training PSNR : with K = 38 is 100
# ('Testing Error with k = 38  is ', 0.04215976334947219)
# Average Testing PSNR : with K = 38 is 13.9687400502
# ('Started training Model ', 39)
# ('Training  Error with k = 39  is ', 0.0)
# Average training PSNR : with K = 39 is 100
# ('Testing Error with k = 39  is ', 0.042292321106469549)
# Average Testing PSNR : with K = 39 is 13.9547216117
# ('Started training Model ', 40)
# ('Training  Error with k = 40  is ', 0.0)
# Average training PSNR : with K = 40 is 100
# ('Testing Error with k = 40  is ', 0.042461924487239906)
# Average Testing PSNR : with K = 40 is 13.9391060501
# ('Started training Model ', 41)
# ('Training  Error with k = 41  is ', 0.0)
# Average training PSNR : with K = 41 is 100
# ('Testing Error with k = 41  is ', 0.042620829328357722)
# Average Testing PSNR : with K = 41 is 13.9218025731
# ('Started training Model ', 42)
# ('Training  Error with k = 42  is ', 0.0)
# Average training PSNR : with K = 42 is 100
# ('Testing Error with k = 42  is ', 0.042724921420161835)
# Average Testing PSNR : with K = 42 is 13.90944139
# ('Started training Model ', 43)
# ('Training  Error with k = 43  is ', 0.0)
# Average training PSNR : with K = 43 is 100
# ('Testing Error with k = 43  is ', 0.042878734161066565)
# Average Testing PSNR : with K = 43 is 13.8948784241
# ('Started training Model ', 44)
# ('Training  Error with k = 44  is ', 0.0)
# Average training PSNR : with K = 44 is 100
# ('Testing Error with k = 44  is ', 0.04304331272520362)
# Average Testing PSNR : with K = 44 is 13.8784511169
# ('Started training Model ', 45)
# ('Training  Error with k = 45  is ', 0.0)
# Average training PSNR : with K = 45 is 100
# ('Testing Error with k = 45  is ', 0.043158504745525593)
# Average Testing PSNR : with K = 45 is 13.8666177935
# ('Started training Model ', 46)
# ('Training  Error with k = 46  is ', 0.0)
# Average training PSNR : with K = 46 is 100
# ('Testing Error with k = 46  is ', 0.043286301035961518)
# Average Testing PSNR : with K = 46 is 13.8534435658
# ('Started training Model ', 47)
# ('Training  Error with k = 47  is ', 0.0)
# Average training PSNR : with K = 47 is 100
# ('Testing Error with k = 47  is ', 0.043446939201290655)
# Average Testing PSNR : with K = 47 is 13.836104746
# ('Started training Model ', 48)
# ('Training  Error with k = 48  is ', 0.0)
# Average training PSNR : with K = 48 is 100
# ('Testing Error with k = 48  is ', 0.043540288944045449)
# Average Testing PSNR : with K = 48 is 13.8268487056
# ('Started training Model ', 49)
# ('Training  Error with k = 49  is ', 0.0)
# Average training PSNR : with K = 49 is 100
# ('Testing Error with k = 49  is ', 0.043652358791946184)
# Average Testing PSNR : with K = 49 is 13.8147960964

# %%
plt.close('all')
fig = plt.figure()
plt.plot(x_axis,test_error)
plt.xlabel('Value of K')
plt.ylabel('Testing Error')
plt.title('K Nearest Regressor with Inverse Weights')
plt.show()

test_error.index(min(test_error))
# Out:
# 6

# %%
min_k = test_error.index(min(test_error))

folder = 'faces'
lst = os.listdir(folder)
imgs_hr = []

for i in lst:
    img = cv2.imread(folder+"/"+i,0)
    img = cv2.resize(img,(0,0), fx=0.25, fy=0.25)
    imgs_hr.append(img)

imgs_hr = np.array(imgs_hr)
imgs_hr = imgs_hr.astype(float)

imgs_lr = imgs_hr[:,::2,::2]

h,w = imgs_hr[0].shape

y = imgs_hr.reshape((len(imgs_hr),w*h))/255
X = imgs_lr.reshape((len(imgs_lr),int(h*w*.25)))/255
imgs_hr = None
imgs_lr = None

model = KNeighborsRegressor(n_neighbors=min_k,weights='distance')


model.fit(X,y)

Train_error = np.mean(np.square(y - model.predict(X)))/len(y)
print ("Training  Error with k = "+ str(min_k)+"  is ",Train_error)

s = 0
pred1 = model.predict(X)
for i in range(len(pred1)):
    s = s + psnr(y[i]*255,pred1[i]*255)
s = s/(i+1)
print ("Average training PSNR : with K = "+str( min_k) + ' is '+str( s))
# Out:
# ('Training  Error with k = 6  is ', 0.0)
# Average training PSNR : with K = 6 is 100

# %%
folder = 'test'

lst = os.listdir(folder)

imgs_hr = []
for i in lst:
    img = cv2.imread(folder+"/"+i,0)
    img = cv2.resize(img,(0,0), fx=0.25, fy=0.25)
    imgs_hr.append(img)
    
imgs_hr = np.array(imgs_hr)
imgs_hr = imgs_hr.astype(float)
imgs_lr = imgs_hr[:,::2,::2]


y = imgs_hr.reshape((len(imgs_hr),w*h))/255
X = imgs_lr.reshape((len(imgs_lr),int(h*w*.25)))/255

#X[0,1] = .99
#X[0,100] = .6

imgs_hr=None
imgs_lr = None
img_id=0

# %%
#Check the Testing Errors

pred = model.predict(X[:,:])



reshaped = pred.reshape((len(pred),h,w))


test = np.mean(np.square(y - model.predict(X)))

print ("Testing Error is ",test)



s = 0

pred1 = model.predict(X)

for i in range(len(pred1)):
    s = s + psnr(y[i]*255,pred1[i]*255)
    
s = s/len(y)

print ("Average Testing PSNR : ", s)



y = y.reshape((len(X),h,w))
# Out:
# ('Testing Error is ', 0.037736358965430747)
# ('Average Testing PSNR : ', 14.426661949643146)

# %%
plt.close('all')

figure = plt.figure()

plt.imshow(reshaped[img_id],cmap='gray')

figure = plt.figure()

plt.imshow(y[img_id],cmap='gray')



plt.show()





reshaped[img_id].shape
# Out:
# (148, 224)
