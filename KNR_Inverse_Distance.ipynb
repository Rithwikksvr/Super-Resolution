# %%
import numpy as np
import cv2
import numpy
import math
import os
import sklearn.linear_model
import sklearn.datasets
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import Data_File
import cost_functions
plt.close('all')

# %%
train_prop = .5
test_prop = .3
v_prop = .2

Data_File.data_writer('Dataset',train_prop,test_prop,v_prop)

# %%
test_error = []
train_error = []
cv_error = []
x_axis = []

train_x,train_y = Data_File.Data('faces')
cv_x,cv_y = Data_File.Data('cross_val')
test_x,test_y = Data_File.Data('test')

for k in range(2,50):    
    
    
    h,w = train_y[0].shape
    
    y = train_y.reshape((len(train_y),w*h))
    X = train_x.reshape((len(train_x),int(h*w*.25)))
    
    model = KNeighborsRegressor(n_neighbors=k,weights = 'distance')
    
    print ("Started training Model "+str(k))
    
    model.fit(X,y)
    
    Train_error = cost_functions.mse_model(X,y,model)
    print ("Training  Error with k = "+ str(k)+"  is ",Train_error)
    
    s = cost_functions.avg_psnr(X,y,model)
    print ("Average training PSNR : with K = "+str( k) + ' is '+str( s))
    
    
    #######CV Data####
    
    
    
    
    y = cv_y.reshape((len(cv_y),w*h))/255
    X = cv_x.reshape((len(cv_x),int(h*w*.25)))/255
    
    img_id=0
    pred = model.predict(X[:,:])
    
    error = cost_functions.mse_model(X,y,model)
    print ("CV Error with k = "+ str(k)+"  is ",error)
    
    s = 0
    pred1 = model.predict(X)
    
    s = cost_functions.avg_psnr(X,y,model)
    
    print ("Average CV PSNR : with K = "+ str(k) + ' is '+ str(s))
    
    reshaped = pred.reshape((len(pred),h,w))
    
    
    cv_error.append(error)
    
    x_axis.append(k)
# Out:
# Started training Model 2
# ('Training  Error with k = 2  is ', 0.0)
# Average training PSNR : with K = 2 is 101
# ('CV Error with k = 2  is ', 0.10069219316198093)
# Average CV PSNR : with K = 2 is 10.2816129081
# Started training Model 3
# ('Training  Error with k = 3  is ', 0.0)
# Average training PSNR : with K = 3 is 101
# ('CV Error with k = 3  is ', 0.10604742718871606)
# Average CV PSNR : with K = 3 is 10.0495373981
# Started training Model 4
# ('Training  Error with k = 4  is ', 0.0)
# Average training PSNR : with K = 4 is 101
# ('CV Error with k = 4  is ', 0.10895347756420885)
# Average CV PSNR : with K = 4 is 9.92845882686
# Started training Model 5
# ('Training  Error with k = 5  is ', 0.0)
# Average training PSNR : with K = 5 is 101
# ('CV Error with k = 5  is ', 0.11432112497334862)
# Average CV PSNR : with K = 5 is 9.71307771044
# Started training Model 6
# ('Training  Error with k = 6  is ', 0.0)
# Average training PSNR : with K = 6 is 101
# ('CV Error with k = 6  is ', 0.11930442747660749)
# Average CV PSNR : with K = 6 is 9.52198640514
# Started training Model 7
# ('Training  Error with k = 7  is ', 0.0)
# Average training PSNR : with K = 7 is 101
# ('CV Error with k = 7  is ', 0.12433523583787512)
# Average CV PSNR : with K = 7 is 9.33700418608
# Started training Model 8
# ('Training  Error with k = 8  is ', 0.0)
# Average training PSNR : with K = 8 is 101
# ('CV Error with k = 8  is ', 0.12372401574764269)
# Average CV PSNR : with K = 8 is 9.3590751986
# Started training Model 9
# ('Training  Error with k = 9  is ', 0.0)
# Average training PSNR : with K = 9 is 101
# ('CV Error with k = 9  is ', 0.12715323182005814)
# Average CV PSNR : with K = 9 is 9.23663063292
# Started training Model 10
# ('Training  Error with k = 10  is ', 0.0)
# Average training PSNR : with K = 10 is 101
# ('CV Error with k = 10  is ', 0.13094098202946294)
# Average CV PSNR : with K = 10 is 9.10516482333
# Started training Model 11
# ('Training  Error with k = 11  is ', 0.0)
# Average training PSNR : with K = 11 is 101
# ('CV Error with k = 11  is ', 0.1326999696294498)
# Average CV PSNR : with K = 11 is 9.04547910287
# Started training Model 12
# ('Training  Error with k = 12  is ', 0.0)
# Average training PSNR : with K = 12 is 101
# ('CV Error with k = 12  is ', 0.13388241025549391)
# Average CV PSNR : with K = 12 is 9.00567072167
# Started training Model 13
# ('Training  Error with k = 13  is ', 0.0)
# Average training PSNR : with K = 13 is 101
# ('CV Error with k = 13  is ', 0.13572014528711979)
# Average CV PSNR : with K = 13 is 8.94461254633
# Started training Model 14
# ('Training  Error with k = 14  is ', 0.0)
# Average training PSNR : with K = 14 is 101
# ('CV Error with k = 14  is ', 0.1380240845506715)
# Average CV PSNR : with K = 14 is 8.86922242588
# Started training Model 15
# ('Training  Error with k = 15  is ', 0.0)
# Average training PSNR : with K = 15 is 101
# ('CV Error with k = 15  is ', 0.14102176301283353)
# Average CV PSNR : with K = 15 is 8.77299363934
# Started training Model 16
# ('Training  Error with k = 16  is ', 0.0)
# Average training PSNR : with K = 16 is 101
# ('CV Error with k = 16  is ', 0.14214777618752356)
# Average CV PSNR : with K = 16 is 8.73737504366
# Started training Model 17
# ('Training  Error with k = 17  is ', 0.0)
# Average training PSNR : with K = 17 is 101
# ('CV Error with k = 17  is ', 0.1433757222204334)
# Average CV PSNR : with K = 17 is 8.69885222373
# Started training Model 18
# ('Training  Error with k = 18  is ', 0.0)
# Average training PSNR : with K = 18 is 101
# ('CV Error with k = 18  is ', 0.14518767452388148)
# Average CV PSNR : with K = 18 is 8.64260649023
# Started training Model 19
# ('Training  Error with k = 19  is ', 0.0)
# Average training PSNR : with K = 19 is 101
# ('CV Error with k = 19  is ', 0.14580377186522811)
# Average CV PSNR : with K = 19 is 8.62364175672
# Started training Model 20
# ('Training  Error with k = 20  is ', 0.0)
# Average training PSNR : with K = 20 is 101
# ('CV Error with k = 20  is ', 0.146544930837961)
# Average CV PSNR : with K = 20 is 8.60093327623
# Started training Model 21
# ('Training  Error with k = 21  is ', 0.0)
# Average training PSNR : with K = 21 is 101
# ('CV Error with k = 21  is ', 0.14780292177956023)
# Average CV PSNR : with K = 21 is 8.56265096092
# Started training Model 22
# ('Training  Error with k = 22  is ', 0.0)
# Average training PSNR : with K = 22 is 101
# ('CV Error with k = 22  is ', 0.14863125367700572)
# Average CV PSNR : with K = 22 is 8.5376212545
# Started training Model 23
# ('Training  Error with k = 23  is ', 0.0)
# Average training PSNR : with K = 23 is 101
# ('CV Error with k = 23  is ', 0.15017816321653382)
# Average CV PSNR : with K = 23 is 8.49124943387
# Started training Model 24
# ('Training  Error with k = 24  is ', 0.0)
# Average training PSNR : with K = 24 is 101
# ('CV Error with k = 24  is ', 0.15142997687815243)
# Average CV PSNR : with K = 24 is 8.45407217407
# Started training Model 25
# ('Training  Error with k = 25  is ', 0.0)
# Average training PSNR : with K = 25 is 101
# ('CV Error with k = 25  is ', 0.15318978568473021)
# Average CV PSNR : with K = 25 is 8.40232450132
# Started training Model 26
# ('Training  Error with k = 26  is ', 0.0)
# Average training PSNR : with K = 26 is 101
# ('CV Error with k = 26  is ', 0.15387196483479865)
# Average CV PSNR : with K = 26 is 8.38242468825
# Started training Model 27
# ('Training  Error with k = 27  is ', 0.0)
# Average training PSNR : with K = 27 is 101
# ('CV Error with k = 27  is ', 0.15326247801609844)
# Average CV PSNR : with K = 27 is 8.40020009265
# Started training Model 28
# ('Training  Error with k = 28  is ', 0.0)
# Average training PSNR : with K = 28 is 101
# ('CV Error with k = 28  is ', 0.15508497322266809)
# Average CV PSNR : with K = 28 is 8.34725696878
# Started training Model 29
# ('Training  Error with k = 29  is ', 0.0)
# Average training PSNR : with K = 29 is 101
# ('CV Error with k = 29  is ', 0.15644681562663496)
# Average CV PSNR : with K = 29 is 8.3081002197
# Started training Model 30
# ('Training  Error with k = 30  is ', 0.0)
# Average training PSNR : with K = 30 is 101
# ('CV Error with k = 30  is ', 0.15792990369606147)
# Average CV PSNR : with K = 30 is 8.26584320971
# Started training Model 31
# ('Training  Error with k = 31  is ', 0.0)
# Average training PSNR : with K = 31 is 101
# ('CV Error with k = 31  is ', 0.15947223755648304)
# Average CV PSNR : with K = 31 is 8.22231702608
# Started training Model 32
# ('Training  Error with k = 32  is ', 0.0)
# Average training PSNR : with K = 32 is 101
# ('CV Error with k = 32  is ', 0.16096880627442492)
# Average CV PSNR : with K = 32 is 8.18048315484
# Started training Model 33
# ('Training  Error with k = 33  is ', 0.0)
# Average training PSNR : with K = 33 is 101
# ('CV Error with k = 33  is ', 0.16239270750337065)
# Average CV PSNR : with K = 33 is 8.14103957683
# Started training Model 34
# ('Training  Error with k = 34  is ', 0.0)
# Average training PSNR : with K = 34 is 101
# ('CV Error with k = 34  is ', 0.16392726419832354)
# Average CV PSNR : with K = 34 is 8.0989163742
# Started training Model 35
# ('Training  Error with k = 35  is ', 0.0)
# Average training PSNR : with K = 35 is 101
# ('CV Error with k = 35  is ', 0.1649120071224745)
# Average CV PSNR : with K = 35 is 8.07209270662
# Started training Model 36
# ('Training  Error with k = 36  is ', 0.0)
# Average training PSNR : with K = 36 is 101
# ('CV Error with k = 36  is ', 0.16648438487514478)
# Average CV PSNR : with K = 36 is 8.02959248495
# Started training Model 37
# ('Training  Error with k = 37  is ', 0.0)
# Average training PSNR : with K = 37 is 101
# ('CV Error with k = 37  is ', 0.16760420760784592)
# Average CV PSNR : with K = 37 is 7.99956852609
# Started training Model 38
# ('Training  Error with k = 38  is ', 0.0)
# Average training PSNR : with K = 38 is 101
# ('CV Error with k = 38  is ', 0.16911130544255898)
# Average CV PSNR : with K = 38 is 7.9594762878
# Started training Model 39
# ('Training  Error with k = 39  is ', 0.0)
# Average training PSNR : with K = 39 is 101
# ('CV Error with k = 39  is ', 0.17075457260530519)
# Average CV PSNR : with K = 39 is 7.91616681917
# Started training Model 40
# ('Training  Error with k = 40  is ', 0.0)
# Average training PSNR : with K = 40 is 101
# ('CV Error with k = 40  is ', 0.17203065075499208)
# Average CV PSNR : with K = 40 is 7.88282141372
# Started training Model 41
# ('Training  Error with k = 41  is ', 0.0)
# Average training PSNR : with K = 41 is 101
# ('CV Error with k = 41  is ', 0.17347446457178545)
# Average CV PSNR : with K = 41 is 7.84538982098
# Started training Model 42
# ('Training  Error with k = 42  is ', 0.0)
# Average training PSNR : with K = 42 is 101
# ('CV Error with k = 42  is ', 0.17480829191873945)
# Average CV PSNR : with K = 42 is 7.81108556094
# Started training Model 43
# ('Training  Error with k = 43  is ', 0.0)
# Average training PSNR : with K = 43 is 101
# ('CV Error with k = 43  is ', 0.17658192235358289)
# Average CV PSNR : with K = 43 is 7.76587332066
# Started training Model 44
# ('Training  Error with k = 44  is ', 0.0)
# Average training PSNR : with K = 44 is 101
# ('CV Error with k = 44  is ', 0.17821771556290672)
# Average CV PSNR : with K = 44 is 7.7245754993
# Started training Model 45
# ('Training  Error with k = 45  is ', 0.0)
# Average training PSNR : with K = 45 is 101
# ('CV Error with k = 45  is ', 0.17908099540262803)
# Average CV PSNR : with K = 45 is 7.70293338963
# Started training Model 46
# ('Training  Error with k = 46  is ', 0.0)
# Average training PSNR : with K = 46 is 101
# ('CV Error with k = 46  is ', 0.18067158988669718)
# Average CV PSNR : with K = 46 is 7.66332954728
# Started training Model 47
# ('Training  Error with k = 47  is ', 0.0)
# Average training PSNR : with K = 47 is 101
# ('CV Error with k = 47  is ', 0.18186659363623911)
# Average CV PSNR : with K = 47 is 7.63380417282
# Started training Model 48
# ('Training  Error with k = 48  is ', 0.0)
# Average training PSNR : with K = 48 is 101
# ('CV Error with k = 48  is ', 0.18297984645419724)
# Average CV PSNR : with K = 48 is 7.60647265136
# Started training Model 49
# ('Training  Error with k = 49  is ', 0.0)
# Average training PSNR : with K = 49 is 101
# ('CV Error with k = 49  is ', 0.18381543420562524)
# Average CV PSNR : with K = 49 is 7.58606715139

# %%
plt.close('all')
fig = plt.figure()
plt.plot(x_axis,cv_error)
plt.xlabel('Value of K')
plt.ylabel('CV Error')
plt.title('K Nearest Regressor with Inverse Weights')
plt.show()
cv_error.index(min(cv_error))
# Out:
# 0

# %%
min_k = 2+cv_error.index(min(cv_error))

y = train_y.reshape((len(train_y),w*h))
X = train_x.reshape((len(train_x),int(h*w*.25)))
model = None
model = KNeighborsRegressor(n_neighbors=min_k,weights='distance')

model.fit(X,y)

s = cost_functions.avg_psnr(X,y,model)
print ("Average training PSNR : with K = "+str( min_k) + ' is '+str( s))
min_k
# Out:
# Average training PSNR : with K = 2 is 101
# 2

# %%
img_id=0

y = test_y.reshape((len(test_y),w*h))
X = test_x.reshape((len(test_x),int(h*w*.25)))

# %%
#Check the Testing Errors

pred = model.predict(X[:,:])
reshaped = pred.reshape((len(pred),h,w))
test_error = cost_functions.mse_model(X,y,model)

print ("Testing Error is ",test_error)
s = cost_functions.avg_psnr(X,y,model)

print ("Average Testing PSNR : ", s)

y = y.reshape((len(X),h,w))
# Out:
# ('Testing Error is ', 0.043881272658752517)
# ('Average Testing PSNR : ', 14.046128953142437)

# %%
plt.close('all')

figure = plt.figure()

plt.imshow(reshaped[img_id],cmap='gray')
plt.title("GEnerated Image")
figure = plt.figure()

plt.imshow(y[img_id],cmap='gray')
plt.title("Ground Truth")

figure = plt.figure()

plt.imshow(X[img_id].reshape((h//2,w//2)),cmap='gray')
plt.title("INput Image")


plt.show()





reshaped[img_id].shape
# Out:
# (74, 112)
