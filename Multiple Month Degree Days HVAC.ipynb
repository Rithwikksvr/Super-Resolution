# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
np.random.seed(30)
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from collections import Counter
import keras
from keras.layers import Conv2D,Dense,Flatten
import keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.layers import Input
from keras.models import Model
# Out:
# /home/rithwik/anaconda/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_data(string,n_months,path='../Datasets for Mid Sem Presentation/'):
    
    X = np.load(path+string+"_x.npy")
    y = np.load(path+string+"_y.npy")
    
    print (X.shape,y.shape)
    
    X = X.reshape((len(X),4,7))/(1000*1.0)
    y = y.reshape((len(y),4,168))/(1000*1.0)
    y = y.reshape((-1,168*4))
    X = np.expand_dims(X,axis=3)
    
    
    
    
    return X,y
        
    
    
    
def relative_cost(truth,pred):
    return np.mean(abs(pred-truth)/(.001+truth))




def relative_metric(truth,pred):
    return K.mean(abs(pred-truth)/(.001+truth))





def mse(truth,pred):
    return np.mean(1000*np.abs((truth-pred)))

# %%
def network():
    
    input_layer = Input(shape=(4,7,1),name="Monthly_Matrix")
    input_layer_2 = Input(shape=(1,),name="Cooling_Degree_Day_Monthly")
    

    op1 = Conv2D(10,kernel_size=(4,1), strides=(1,1),name="Filter_4X1")(input_layer)
    
    op1 = Flatten()(op1)
    
    
    
    op2 = Conv2D(10,kernel_size=(1,7), strides=(1,1),name="Filter_1X7")(input_layer)
    
    op2 = Flatten()(op2)
    
    
    op3 = Conv2D(10,kernel_size=(1,2),strides=(1,1),name="Filter_1X2")(input_layer)
    
    op3 = Flatten()(op3)
    
    op4 = Conv2D(10,kernel_size=(2,1),strides=(1,1),name="Filter_2X1")(input_layer)
    
    op4 = Flatten()(op4)
    
    #op5 = Conv2D(20,kernel_size=(3,3),strides=(1,1),padding='same')(input_layer)
    
    #op5 = Conv2D(20,3,strides=(1,1),padding='same')(input_layer)
    
    #op5 = Flatten()(op5)
    
    #op5 =  keras.layers.Dropout(.2)(op5)
    
    #op5  = Dense(168*4)(op5)
    
    
    
    
    
    
    
    
    
    merge_layer = keras.layers.concatenate([op1, op2, op3,op4],name="Concatenation_1")
    

    
    merge_layer =  keras.layers.Dropout(.1)(merge_layer)
    
    
    
    merge_layer = keras.layers.concatenate(([merge_layer,input_layer_2]),name="Concatenation_2")
    
    final_layer = Dense(168*4,name="Output_Dense",activation='relu')(merge_layer)
    
    
    #final_layer = keras.layers.LeakyReLU(alpha=0.01)(final_layer)
    
    #predictions = Dense(1, activation='sigmoid')(merge_layer)

    
    
    
    model = Model(inputs=[input_layer,input_layer_2], outputs=final_layer)

    
    return model

# %%
test_x,test_y = load_data('test_data',1)
train_x,train_y = load_data("train_data_1",3)
v_x,v_y = load_data("val_data_2",3)
# Out:
# ((18, 28), (18, 672))
# ((207, 28), (207, 672))
# ((19, 28), (19, 672))

# %%
vals = [16,18,21]

# %%
train_temp = np.array(vals*(len(train_x)/3))
v_temp = np.array([vals[1]]*(len(v_x)))
test_temp = np.array([vals[1]]*(len(test_x)))

# %%
v_temp
# Out:
# array([18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18,
#        18, 18])

# %%
#test_x[0]

# %%
model = network()

# %%
dir_name = "Multiple Month Degree Days HVAC"

# %%
model = network()
n_epochs = 3000
sgd = keras.optimizers.SGD(lr=0.001)
rmsprop  = keras.optimizers.RMSprop(lr=.001)
adagrad = keras.optimizers.adagrad(lr=.001)
model.compile(optimizer='sgd', loss='mean_squared_error',metrics=[relative_metric])
filepath="weights.best.h5"
checkpoint = ModelCheckpoint(dir_name+'/single-model-{epoch:03d}.h5', verbose=5, monitor='val_loss',save_best_only=True, mode='auto')  
model.fit([train_x,train_temp], train_y, epochs=n_epochs, validation_data=[[v_x,v_temp],v_y], callbacks=[checkpoint], verbose=5)
# Out:
# Train on 207 samples, validate on 19 samples
# Epoch 1/3000
#
# Epoch 00001: val_loss improved from inf to 0.35720, saving model to Multiple Month Degree Days HVAC/single-model-001.h5
# Epoch 2/3000
#
# Epoch 00002: val_loss improved from 0.35720 to 0.30038, saving model to Multiple Month Degree Days HVAC/single-model-002.h5
# Epoch 3/3000
#
# Epoch 00003: val_loss improved from 0.30038 to 0.27865, saving model to Multiple Month Degree Days HVAC/single-model-003.h5
# Epoch 4/3000
#
# Epoch 00004: val_loss improved from 0.27865 to 0.26753, saving model to Multiple Month Degree Days HVAC/single-model-004.h5
# Epoch 5/3000
#
# Epoch 00005: val_loss improved from 0.26753 to 0.26100, saving model to Multiple Month Degree Days HVAC/single-model-005.h5
# Epoch 6/3000
#
# Epoch 00006: val_loss improved from 0.26100 to 0.25647, saving model to Multiple Month Degree Days HVAC/single-model-006.h5
# Epoch 7/3000
#
# Epoch 00007: val_loss improved from 0.25647 to 0.25328, saving model to Multiple Month Degree Days HVAC/single-model-007.h5
# Epoch 8/3000
#
# Epoch 00008: val_loss improved from 0.25328 to 0.25086, saving model to Multiple Month Degree Days HVAC/single-model-008.h5
# Epoch 9/3000
#
# Epoch 00009: val_loss improved from 0.25086 to 0.24921, saving model to Multiple Month Degree Days HVAC/single-model-009.h5
# Epoch 10/3000
#
# Epoch 00010: val_loss improved from 0.24921 to 0.24785, saving model to Multiple Month Degree Days HVAC/single-model-010.h5
# Epoch 11/3000
#
# Epoch 00011: val_loss improved from 0.24785 to 0.24681, saving model to Multiple Month Degree Days HVAC/single-model-011.h5
# Epoch 12/3000
#
# Epoch 00012: val_loss improved from 0.24681 to 0.24582, saving model to Multiple Month Degree Days HVAC/single-model-012.h5
# Epoch 13/3000
#
# Epoch 00013: val_loss improved from 0.24582 to 0.24497, saving model to Multiple Month Degree Days HVAC/single-model-013.h5
# Epoch 14/3000
#
# Epoch 00014: val_loss improved from 0.24497 to 0.24426, saving model to Multiple Month Degree Days HVAC/single-model-014.h5
# Epoch 15/3000
#
# Epoch 00015: val_loss improved from 0.24426 to 0.24357, saving model to Multiple Month Degree Days HVAC/single-model-015.h5
# Epoch 16/3000
#
# Epoch 00016: val_loss improved from 0.24357 to 0.24311, saving model to Multiple Month Degree Days HVAC/single-model-016.h5
# Epoch 17/3000
#
# Epoch 00017: val_loss improved from 0.24311 to 0.24256, saving model to Multiple Month Degree Days HVAC/single-model-017.h5
# Epoch 18/3000
#
# Epoch 00018: val_loss improved from 0.24256 to 0.24219, saving model to Multiple Month Degree Days HVAC/single-model-018.h5
# Epoch 19/3000
#
# Epoch 00019: val_loss improved from 0.24219 to 0.24188, saving model to Multiple Month Degree Days HVAC/single-model-019.h5
# Epoch 20/3000
#
# Epoch 00020: val_loss improved from 0.24188 to 0.24152, saving model to Multiple Month Degree Days HVAC/single-model-020.h5
# Epoch 21/3000
#
# Epoch 00021: val_loss improved from 0.24152 to 0.24119, saving model to Multiple Month Degree Days HVAC/single-model-021.h5
# Epoch 22/3000
#
# Epoch 00022: val_loss improved from 0.24119 to 0.24097, saving model to Multiple Month Degree Days HVAC/single-model-022.h5
# Epoch 23/3000
#
# Epoch 00023: val_loss improved from 0.24097 to 0.24078, saving model to Multiple Month Degree Days HVAC/single-model-023.h5
# Epoch 24/3000
#
# Epoch 00024: val_loss improved from 0.24078 to 0.24056, saving model to Multiple Month Degree Days HVAC/single-model-024.h5
# Epoch 25/3000
#
# Epoch 00025: val_loss improved from 0.24056 to 0.24042, saving model to Multiple Month Degree Days HVAC/single-model-025.h5
# Epoch 26/3000
#
# Epoch 00026: val_loss improved from 0.24042 to 0.24027, saving model to Multiple Month Degree Days HVAC/single-model-026.h5
# Epoch 27/3000
#
# Epoch 00027: val_loss improved from 0.24027 to 0.24011, saving model to Multiple Month Degree Days HVAC/single-model-027.h5
# Epoch 28/3000
#
# Epoch 00028: val_loss improved from 0.24011 to 0.23990, saving model to Multiple Month Degree Days HVAC/single-model-028.h5
# Epoch 29/3000
#
# Epoch 00029: val_loss improved from 0.23990 to 0.23974, saving model to Multiple Month Degree Days HVAC/single-model-029.h5
# Epoch 30/3000
#
# Epoch 00030: val_loss improved from 0.23974 to 0.23966, saving model to Multiple Month Degree Days HVAC/single-model-030.h5
# Epoch 31/3000
#
# Epoch 00031: val_loss improved from 0.23966 to 0.23960, saving model to Multiple Month Degree Days HVAC/single-model-031.h5
# Epoch 32/3000
#
# Epoch 00032: val_loss improved from 0.23960 to 0.23945, saving model to Multiple Month Degree Days HVAC/single-model-032.h5
# Epoch 33/3000
#
# Epoch 00033: val_loss improved from 0.23945 to 0.23938, saving model to Multiple Month Degree Days HVAC/single-model-033.h5
# Epoch 34/3000
#
# Epoch 00034: val_loss improved from 0.23938 to 0.23926, saving model to Multiple Month Degree Days HVAC/single-model-034.h5
# Epoch 35/3000
#
# Epoch 00035: val_loss improved from 0.23926 to 0.23913, saving model to Multiple Month Degree Days HVAC/single-model-035.h5
# Epoch 36/3000
#
# Epoch 00036: val_loss improved from 0.23913 to 0.23906, saving model to Multiple Month Degree Days HVAC/single-model-036.h5
# Epoch 37/3000
#
# Epoch 00037: val_loss improved from 0.23906 to 0.23899, saving model to Multiple Month Degree Days HVAC/single-model-037.h5
# Epoch 38/3000
#
# Epoch 00038: val_loss improved from 0.23899 to 0.23892, saving model to Multiple Month Degree Days HVAC/single-model-038.h5
# Epoch 39/3000
#
# Epoch 00039: val_loss improved from 0.23892 to 0.23889, saving model to Multiple Month Degree Days HVAC/single-model-039.h5
# Epoch 40/3000
#
# Epoch 00040: val_loss improved from 0.23889 to 0.23880, saving model to Multiple Month Degree Days HVAC/single-model-040.h5
# Epoch 41/3000
#
# Epoch 00041: val_loss improved from 0.23880 to 0.23873, saving model to Multiple Month Degree Days HVAC/single-model-041.h5
# Epoch 42/3000
#
# Epoch 00042: val_loss improved from 0.23873 to 0.23868, saving model to Multiple Month Degree Days HVAC/single-model-042.h5
# Epoch 43/3000
#
# Epoch 00043: val_loss improved from 0.23868 to 0.23858, saving model to Multiple Month Degree Days HVAC/single-model-043.h5
# Epoch 44/3000
#
# Epoch 00044: val_loss improved from 0.23858 to 0.23854, saving model to Multiple Month Degree Days HVAC/single-model-044.h5
# Epoch 45/3000
#
# Epoch 00045: val_loss improved from 0.23854 to 0.23846, saving model to Multiple Month Degree Days HVAC/single-model-045.h5
# Epoch 46/3000
#
# Epoch 00046: val_loss improved from 0.23846 to 0.23840, saving model to Multiple Month Degree Days HVAC/single-model-046.h5
# Epoch 47/3000
#
# Epoch 00047: val_loss improved from 0.23840 to 0.23838, saving model to Multiple Month Degree Days HVAC/single-model-047.h5
# Epoch 48/3000
#
# Epoch 00048: val_loss improved from 0.23838 to 0.23835, saving model to Multiple Month Degree Days HVAC/single-model-048.h5
# Epoch 49/3000
#
# Epoch 00049: val_loss improved from 0.23835 to 0.23831, saving model to Multiple Month Degree Days HVAC/single-model-049.h5
# Epoch 50/3000
#
# Epoch 00050: val_loss improved from 0.23831 to 0.23829, saving model to Multiple Month Degree Days HVAC/single-model-050.h5
# Epoch 51/3000
#
# Epoch 00051: val_loss improved from 0.23829 to 0.23826, saving model to Multiple Month Degree Days HVAC/single-model-051.h5
# Epoch 52/3000
#
# Epoch 00052: val_loss did not improve
# Epoch 53/3000
#
# Epoch 00053: val_loss did not improve
# Epoch 54/3000
#
# Epoch 00054: val_loss improved from 0.23826 to 0.23823, saving model to Multiple Month Degree Days HVAC/single-model-054.h5
# Epoch 55/3000
#
# Epoch 00055: val_loss improved from 0.23823 to 0.23821, saving model to Multiple Month Degree Days HVAC/single-model-055.h5
# Epoch 56/3000
#
# Epoch 00056: val_loss improved from 0.23821 to 0.23817, saving model to Multiple Month Degree Days HVAC/single-model-056.h5
# Epoch 57/3000
#
# Epoch 00057: val_loss improved from 0.23817 to 0.23809, saving model to Multiple Month Degree Days HVAC/single-model-057.h5
# Epoch 58/3000
#
# Epoch 00058: val_loss did not improve
# Epoch 59/3000
#
# Epoch 00059: val_loss improved from 0.23809 to 0.23806, saving model to Multiple Month Degree Days HVAC/single-model-059.h5
# Epoch 60/3000
#
# Epoch 00060: val_loss improved from 0.23806 to 0.23805, saving model to Multiple Month Degree Days HVAC/single-model-060.h5
# Epoch 61/3000
#
# Epoch 00061: val_loss improved from 0.23805 to 0.23803, saving model to Multiple Month Degree Days HVAC/single-model-061.h5
# Epoch 62/3000
#
# Epoch 00062: val_loss improved from 0.23803 to 0.23801, saving model to Multiple Month Degree Days HVAC/single-model-062.h5
# Epoch 63/3000
#
# Epoch 00063: val_loss improved from 0.23801 to 0.23801, saving model to Multiple Month Degree Days HVAC/single-model-063.h5
# Epoch 64/3000
#
# Epoch 00064: val_loss improved from 0.23801 to 0.23800, saving model to Multiple Month Degree Days HVAC/single-model-064.h5
# Epoch 65/3000
#
# Epoch 00065: val_loss improved from 0.23800 to 0.23797, saving model to Multiple Month Degree Days HVAC/single-model-065.h5
# Epoch 66/3000
#
# Epoch 00066: val_loss did not improve
# Epoch 67/3000
#
# Epoch 00067: val_loss improved from 0.23797 to 0.23795, saving model to Multiple Month Degree Days HVAC/single-model-067.h5
# Epoch 68/3000
#
# Epoch 00068: val_loss improved from 0.23795 to 0.23793, saving model to Multiple Month Degree Days HVAC/single-model-068.h5
# Epoch 69/3000
#
# Epoch 00069: val_loss improved from 0.23793 to 0.23792, saving model to Multiple Month Degree Days HVAC/single-model-069.h5
# Epoch 70/3000
#
# Epoch 00070: val_loss improved from 0.23792 to 0.23792, saving model to Multiple Month Degree Days HVAC/single-model-070.h5
# Epoch 71/3000
#
# Epoch 00071: val_loss improved from 0.23792 to 0.23792, saving model to Multiple Month Degree Days HVAC/single-model-071.h5
# Epoch 72/3000
#
# Epoch 00072: val_loss improved from 0.23792 to 0.23791, saving model to Multiple Month Degree Days HVAC/single-model-072.h5
# Epoch 73/3000
#
# Epoch 00073: val_loss improved from 0.23791 to 0.23790, saving model to Multiple Month Degree Days HVAC/single-model-073.h5
# Epoch 74/3000
#
# Epoch 00074: val_loss did not improve
# Epoch 75/3000
#
# Epoch 00075: val_loss did not improve
# Epoch 76/3000
#
# Epoch 00076: val_loss improved from 0.23790 to 0.23789, saving model to Multiple Month Degree Days HVAC/single-model-076.h5
# Epoch 77/3000
#
# Epoch 00077: val_loss improved from 0.23789 to 0.23787, saving model to Multiple Month Degree Days HVAC/single-model-077.h5
# Epoch 78/3000
#
# Epoch 00078: val_loss improved from 0.23787 to 0.23787, saving model to Multiple Month Degree Days HVAC/single-model-078.h5
# Epoch 79/3000
#
# Epoch 00079: val_loss improved from 0.23787 to 0.23782, saving model to Multiple Month Degree Days HVAC/single-model-079.h5
# Epoch 80/3000
#
# Epoch 00080: val_loss improved from 0.23782 to 0.23781, saving model to Multiple Month Degree Days HVAC/single-model-080.h5
# Epoch 81/3000
#
# Epoch 00081: val_loss did not improve
# Epoch 82/3000
#
# Epoch 00082: val_loss did not improve
# Epoch 83/3000
#
# Epoch 00083: val_loss did not improve
# Epoch 84/3000
#
# Epoch 00084: val_loss improved from 0.23781 to 0.23781, saving model to Multiple Month Degree Days HVAC/single-model-084.h5
# Epoch 85/3000
#
# Epoch 00085: val_loss did not improve
# Epoch 86/3000
#
# Epoch 00086: val_loss improved from 0.23781 to 0.23779, saving model to Multiple Month Degree Days HVAC/single-model-086.h5
# Epoch 87/3000
#
# Epoch 00087: val_loss improved from 0.23779 to 0.23779, saving model to Multiple Month Degree Days HVAC/single-model-087.h5
# Epoch 88/3000
#
# Epoch 00088: val_loss improved from 0.23779 to 0.23778, saving model to Multiple Month Degree Days HVAC/single-model-088.h5
# Epoch 89/3000
#
# Epoch 00089: val_loss did not improve
# Epoch 90/3000
#
# Epoch 00090: val_loss improved from 0.23778 to 0.23777, saving model to Multiple Month Degree Days HVAC/single-model-090.h5
# Epoch 91/3000
#
# Epoch 00091: val_loss improved from 0.23777 to 0.23777, saving model to Multiple Month Degree Days HVAC/single-model-091.h5
# Epoch 92/3000
#
# Epoch 00092: val_loss improved from 0.23777 to 0.23777, saving model to Multiple Month Degree Days HVAC/single-model-092.h5
# Epoch 93/3000
#
# Epoch 00093: val_loss improved from 0.23777 to 0.23776, saving model to Multiple Month Degree Days HVAC/single-model-093.h5
# Epoch 94/3000
#
# Epoch 00094: val_loss improved from 0.23776 to 0.23775, saving model to Multiple Month Degree Days HVAC/single-model-094.h5
# Epoch 95/3000
#
# Epoch 00095: val_loss did not improve
# Epoch 96/3000
#
# Epoch 00096: val_loss improved from 0.23775 to 0.23775, saving model to Multiple Month Degree Days HVAC/single-model-096.h5
# Epoch 97/3000
#
# Epoch 00097: val_loss improved from 0.23775 to 0.23775, saving model to Multiple Month Degree Days HVAC/single-model-097.h5
# Epoch 98/3000
#
# Epoch 00098: val_loss improved from 0.23775 to 0.23774, saving model to Multiple Month Degree Days HVAC/single-model-098.h5
# Epoch 99/3000
#
# Epoch 00099: val_loss improved from 0.23774 to 0.23773, saving model to Multiple Month Degree Days HVAC/single-model-099.h5
# Epoch 100/3000
#
# Epoch 00100: val_loss improved from 0.23773 to 0.23766, saving model to Multiple Month Degree Days HVAC/single-model-100.h5
# Epoch 101/3000
#
# Epoch 00101: val_loss improved from 0.23766 to 0.23763, saving model to Multiple Month Degree Days HVAC/single-model-101.h5
# Epoch 102/3000
#
# Epoch 00102: val_loss improved from 0.23763 to 0.23761, saving model to Multiple Month Degree Days HVAC/single-model-102.h5
# Epoch 103/3000
#
# Epoch 00103: val_loss did not improve
# Epoch 104/3000
#
# Epoch 00104: val_loss improved from 0.23761 to 0.23760, saving model to Multiple Month Degree Days HVAC/single-model-104.h5
# Epoch 105/3000
#
# Epoch 00105: val_loss improved from 0.23760 to 0.23759, saving model to Multiple Month Degree Days HVAC/single-model-105.h5
# Epoch 106/3000
#
# Epoch 00106: val_loss improved from 0.23759 to 0.23758, saving model to Multiple Month Degree Days HVAC/single-model-106.h5
# Epoch 107/3000
#
# Epoch 00107: val_loss improved from 0.23758 to 0.23757, saving model to Multiple Month Degree Days HVAC/single-model-107.h5
# Epoch 108/3000
#
# Epoch 00108: val_loss improved from 0.23757 to 0.23757, saving model to Multiple Month Degree Days HVAC/single-model-108.h5
# Epoch 109/3000
#
# Epoch 00109: val_loss improved from 0.23757 to 0.23757, saving model to Multiple Month Degree Days HVAC/single-model-109.h5
# Epoch 110/3000
#
# Epoch 00110: val_loss improved from 0.23757 to 0.23756, saving model to Multiple Month Degree Days HVAC/single-model-110.h5
# Epoch 111/3000
#
# Epoch 00111: val_loss did not improve
# Epoch 112/3000
#
# Epoch 00112: val_loss improved from 0.23756 to 0.23756, saving model to Multiple Month Degree Days HVAC/single-model-112.h5
# Epoch 113/3000
#
# Epoch 00113: val_loss improved from 0.23756 to 0.23753, saving model to Multiple Month Degree Days HVAC/single-model-113.h5
# Epoch 114/3000
#
# Epoch 00114: val_loss improved from 0.23753 to 0.23753, saving model to Multiple Month Degree Days HVAC/single-model-114.h5
# Epoch 115/3000
#
# Epoch 00115: val_loss improved from 0.23753 to 0.23752, saving model to Multiple Month Degree Days HVAC/single-model-115.h5
# Epoch 116/3000
#
# Epoch 00116: val_loss improved from 0.23752 to 0.23751, saving model to Multiple Month Degree Days HVAC/single-model-116.h5
# Epoch 117/3000
#
# Epoch 00117: val_loss did not improve
# Epoch 118/3000
#
# Epoch 00118: val_loss did not improve
# Epoch 119/3000
#
# Epoch 00119: val_loss improved from 0.23751 to 0.23750, saving model to Multiple Month Degree Days HVAC/single-model-119.h5
# Epoch 120/3000
#
# Epoch 00120: val_loss improved from 0.23750 to 0.23749, saving model to Multiple Month Degree Days HVAC/single-model-120.h5
# Epoch 121/3000
#
# Epoch 00121: val_loss improved from 0.23749 to 0.23749, saving model to Multiple Month Degree Days HVAC/single-model-121.h5
# Epoch 122/3000
#
# Epoch 00122: val_loss did not improve
# Epoch 123/3000
#
# Epoch 00123: val_loss did not improve
# Epoch 124/3000
#
# Epoch 00124: val_loss improved from 0.23749 to 0.23749, saving model to Multiple Month Degree Days HVAC/single-model-124.h5
# Epoch 125/3000
#
# Epoch 00125: val_loss improved from 0.23749 to 0.23748, saving model to Multiple Month Degree Days HVAC/single-model-125.h5
# Epoch 126/3000
#
# Epoch 00126: val_loss did not improve
# Epoch 127/3000
#
# Epoch 00127: val_loss did not improve
# Epoch 128/3000
#
# Epoch 00128: val_loss improved from 0.23748 to 0.23748, saving model to Multiple Month Degree Days HVAC/single-model-128.h5
# Epoch 129/3000
#
# Epoch 00129: val_loss did not improve
# Epoch 130/3000
#
# Epoch 00130: val_loss did not improve
# Epoch 131/3000
#
# Epoch 00131: val_loss did not improve
# Epoch 132/3000
#
# Epoch 00132: val_loss did not improve
# Epoch 133/3000
#
# Epoch 00133: val_loss did not improve
# Epoch 134/3000
#
# Epoch 00134: val_loss did not improve
# Epoch 135/3000
#
# Epoch 00135: val_loss did not improve
# Epoch 136/3000
#
# Epoch 00136: val_loss did not improve
# Epoch 137/3000
#
# Epoch 00137: val_loss did not improve
# Epoch 138/3000
#
# Epoch 00138: val_loss did not improve
# Epoch 139/3000
#
# Epoch 00139: val_loss did not improve
# Epoch 140/3000
#
# Epoch 00140: val_loss did not improve
# Epoch 141/3000
#
# Epoch 00141: val_loss did not improve
# Epoch 142/3000
#
# Epoch 00142: val_loss did not improve
# Epoch 143/3000
#
# Epoch 00143: val_loss did not improve
# Epoch 144/3000
#
# Epoch 00144: val_loss did not improve
# Epoch 145/3000
#
# Epoch 00145: val_loss did not improve
# Epoch 146/3000
#
# Epoch 00146: val_loss did not improve
# Epoch 147/3000
#
# Epoch 00147: val_loss did not improve
# Epoch 148/3000
#
# Epoch 00148: val_loss did not improve
# Epoch 149/3000
#
# Epoch 00149: val_loss improved from 0.23748 to 0.23748, saving model to Multiple Month Degree Days HVAC/single-model-149.h5
# Epoch 150/3000
#
# Epoch 00150: val_loss improved from 0.23748 to 0.23747, saving model to Multiple Month Degree Days HVAC/single-model-150.h5
# Epoch 151/3000
#
# Epoch 00151: val_loss improved from 0.23747 to 0.23747, saving model to Multiple Month Degree Days HVAC/single-model-151.h5
# Epoch 152/3000
#
# Epoch 00152: val_loss improved from 0.23747 to 0.23747, saving model to Multiple Month Degree Days HVAC/single-model-152.h5
# Epoch 153/3000
#
# Epoch 00153: val_loss improved from 0.23747 to 0.23747, saving model to Multiple Month Degree Days HVAC/single-model-153.h5
# Epoch 154/3000
#
# Epoch 00154: val_loss improved from 0.23747 to 0.23746, saving model to Multiple Month Degree Days HVAC/single-model-154.h5
# Epoch 155/3000
#
# Epoch 00155: val_loss improved from 0.23746 to 0.23745, saving model to Multiple Month Degree Days HVAC/single-model-155.h5
# Epoch 156/3000
#
# Epoch 00156: val_loss improved from 0.23745 to 0.23745, saving model to Multiple Month Degree Days HVAC/single-model-156.h5
# Epoch 157/3000
#
# Epoch 00157: val_loss improved from 0.23745 to 0.23745, saving model to Multiple Month Degree Days HVAC/single-model-157.h5
# Epoch 158/3000
#
# Epoch 00158: val_loss improved from 0.23745 to 0.23745, saving model to Multiple Month Degree Days HVAC/single-model-158.h5
# Epoch 159/3000
#
# Epoch 00159: val_loss improved from 0.23745 to 0.23745, saving model to Multiple Month Degree Days HVAC/single-model-159.h5
# Epoch 160/3000
#
# Epoch 00160: val_loss improved from 0.23745 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-160.h5
# Epoch 161/3000
#
# Epoch 00161: val_loss did not improve
# Epoch 162/3000
#
# Epoch 00162: val_loss did not improve
# Epoch 163/3000
#
# Epoch 00163: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-163.h5
# Epoch 164/3000
#
# Epoch 00164: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-164.h5
# Epoch 165/3000
#
# Epoch 00165: val_loss did not improve
# Epoch 166/3000
#
# Epoch 00166: val_loss did not improve
# Epoch 167/3000
#
# Epoch 00167: val_loss did not improve
# Epoch 168/3000
#
# Epoch 00168: val_loss did not improve
# Epoch 169/3000
#
# Epoch 00169: val_loss did not improve
# Epoch 170/3000
#
# Epoch 00170: val_loss did not improve
# Epoch 171/3000
#
# Epoch 00171: val_loss did not improve
# Epoch 172/3000
#
# Epoch 00172: val_loss did not improve
# Epoch 173/3000
#
# Epoch 00173: val_loss did not improve
# Epoch 174/3000
#
# Epoch 00174: val_loss did not improve
# Epoch 175/3000
#
# Epoch 00175: val_loss did not improve
# Epoch 176/3000
#
# Epoch 00176: val_loss did not improve
# Epoch 177/3000
#
# Epoch 00177: val_loss did not improve
# Epoch 178/3000
#
# Epoch 00178: val_loss did not improve
# Epoch 179/3000
#
# Epoch 00179: val_loss did not improve
# Epoch 180/3000
#
# Epoch 00180: val_loss did not improve
# Epoch 181/3000
#
# Epoch 00181: val_loss did not improve
# Epoch 182/3000
#
# Epoch 00182: val_loss did not improve
# Epoch 183/3000
#
# Epoch 00183: val_loss did not improve
# Epoch 184/3000
#
# Epoch 00184: val_loss did not improve
# Epoch 185/3000
#
# Epoch 00185: val_loss did not improve
# Epoch 186/3000
#
# Epoch 00186: val_loss did not improve
# Epoch 187/3000
#
# Epoch 00187: val_loss did not improve
# Epoch 188/3000
#
# Epoch 00188: val_loss did not improve
# Epoch 189/3000
#
# Epoch 00189: val_loss did not improve
# Epoch 190/3000
#
# Epoch 00190: val_loss did not improve
# Epoch 191/3000
#
# Epoch 00191: val_loss did not improve
# Epoch 192/3000
#
# Epoch 00192: val_loss did not improve
# Epoch 193/3000
#
# Epoch 00193: val_loss did not improve
# Epoch 194/3000
#
# Epoch 00194: val_loss did not improve
# Epoch 195/3000
#
# Epoch 00195: val_loss did not improve
# Epoch 196/3000
#
# Epoch 00196: val_loss did not improve
# Epoch 197/3000
#
# Epoch 00197: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-197.h5
# Epoch 198/3000
#
# Epoch 00198: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-198.h5
# Epoch 199/3000
#
# Epoch 00199: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-199.h5
# Epoch 200/3000
#
# Epoch 00200: val_loss improved from 0.23744 to 0.23744, saving model to Multiple Month Degree Days HVAC/single-model-200.h5
# Epoch 201/3000
#
# Epoch 00201: val_loss did not improve
# Epoch 202/3000
#
# Epoch 00202: val_loss did not improve
# Epoch 203/3000
#
# Epoch 00203: val_loss did not improve
# Epoch 204/3000
#
# Epoch 00204: val_loss did not improve
# Epoch 205/3000
#
# Epoch 00205: val_loss did not improve
# Epoch 206/3000
#
# Epoch 00206: val_loss did not improve
# Epoch 207/3000
#
# Epoch 00207: val_loss did not improve
# Epoch 208/3000
#
# Epoch 00208: val_loss did not improve
# Epoch 209/3000
#
# Epoch 00209: val_loss did not improve
# Epoch 210/3000
#
# Epoch 00210: val_loss did not improve
# Epoch 211/3000
#
# Epoch 00211: val_loss did not improve
# Epoch 212/3000
#
# Epoch 00212: val_loss did not improve
# Epoch 213/3000
#
# Epoch 00213: val_loss did not improve
# Epoch 214/3000
#
# Epoch 00214: val_loss did not improve
# Epoch 215/3000
#
# Epoch 00215: val_loss did not improve
# Epoch 216/3000
#
# Epoch 00216: val_loss did not improve
# Epoch 217/3000
#
# Epoch 00217: val_loss did not improve
# Epoch 218/3000
#
# Epoch 00218: val_loss did not improve
# Epoch 219/3000
#
# Epoch 00219: val_loss did not improve
# Epoch 220/3000
#
# Epoch 00220: val_loss did not improve
# Epoch 221/3000
#
# Epoch 00221: val_loss did not improve
# Epoch 222/3000
#
# Epoch 00222: val_loss did not improve
# Epoch 223/3000
#
# Epoch 00223: val_loss did not improve
# Epoch 224/3000
#
# Epoch 00224: val_loss did not improve
# Epoch 225/3000
#
# Epoch 00225: val_loss did not improve
# Epoch 226/3000
#
# Epoch 00226: val_loss did not improve
# Epoch 227/3000
#
# Epoch 00227: val_loss did not improve
# Epoch 228/3000
#
# Epoch 00228: val_loss did not improve
# Epoch 229/3000
#
# Epoch 00229: val_loss did not improve
# Epoch 230/3000
#
# Epoch 00230: val_loss did not improve
# Epoch 231/3000
#
# Epoch 00231: val_loss did not improve
# Epoch 232/3000
#
# Epoch 00232: val_loss did not improve
# Epoch 233/3000
#
# Epoch 00233: val_loss did not improve
# Epoch 234/3000
#
# Epoch 00234: val_loss did not improve
# Epoch 235/3000
#
# Epoch 00235: val_loss did not improve
# Epoch 236/3000
#
# Epoch 00236: val_loss did not improve
# Epoch 237/3000
#
# Epoch 00237: val_loss did not improve
# Epoch 238/3000
#
# Epoch 00238: val_loss did not improve
# Epoch 239/3000
#
# Epoch 00239: val_loss did not improve
# Epoch 240/3000
#
# Epoch 00240: val_loss did not improve
# Epoch 241/3000
#
# Epoch 00241: val_loss did not improve
# Epoch 242/3000
#
# Epoch 00242: val_loss did not improve
# Epoch 243/3000
#
# Epoch 00243: val_loss did not improve
# Epoch 244/3000
#
# Epoch 00244: val_loss did not improve
# Epoch 245/3000
#
# Epoch 00245: val_loss did not improve
# Epoch 246/3000
#
# Epoch 00246: val_loss did not improve
# Epoch 247/3000
#
# Epoch 00247: val_loss did not improve
# Epoch 248/3000
#
# Epoch 00248: val_loss did not improve
# Epoch 249/3000
#
# Epoch 00249: val_loss did not improve
# Epoch 250/3000
#
# Epoch 00250: val_loss did not improve
# Epoch 251/3000
#
# Epoch 00251: val_loss did not improve
# Epoch 252/3000
#
# Epoch 00252: val_loss did not improve
# Epoch 253/3000
#
# Epoch 00253: val_loss did not improve
# Epoch 254/3000
#
# Epoch 00254: val_loss did not improve
# Epoch 255/3000
#
# Epoch 00255: val_loss did not improve
# Epoch 256/3000
#
# Epoch 00256: val_loss did not improve
# Epoch 257/3000
#
# Epoch 00257: val_loss did not improve
# Epoch 258/3000
#
# Epoch 00258: val_loss did not improve
# Epoch 259/3000
#
# Epoch 00259: val_loss did not improve
# Epoch 260/3000
#
# Epoch 00260: val_loss did not improve
# Epoch 261/3000
#
# Epoch 00261: val_loss did not improve
# Epoch 262/3000
#
# Epoch 00262: val_loss did not improve
# Epoch 263/3000
#
# Epoch 00263: val_loss did not improve
# Epoch 264/3000
#
# Epoch 00264: val_loss did not improve
# Epoch 265/3000
#
# Epoch 00265: val_loss did not improve
# Epoch 266/3000
#
# Epoch 00266: val_loss did not improve
# Epoch 267/3000
#
# Epoch 00267: val_loss did not improve
# Epoch 268/3000
#
# Epoch 00268: val_loss did not improve
# Epoch 269/3000
#
# Epoch 00269: val_loss did not improve
# Epoch 270/3000
#
# Epoch 00270: val_loss did not improve
# Epoch 271/3000
#
# Epoch 00271: val_loss did not improve
# Epoch 272/3000
#
# Epoch 00272: val_loss did not improve
# Epoch 273/3000
#
# Epoch 00273: val_loss did not improve
# Epoch 274/3000
#
# Epoch 00274: val_loss did not improve
# Epoch 275/3000
#
# Epoch 00275: val_loss did not improve
# Epoch 276/3000
#
# Epoch 00276: val_loss did not improve
# Epoch 277/3000
#
# Epoch 00277: val_loss did not improve
# Epoch 278/3000
#
# Epoch 00278: val_loss did not improve
# Epoch 279/3000
#
# Epoch 00279: val_loss did not improve
# Epoch 280/3000
#
# Epoch 00280: val_loss did not improve
# Epoch 281/3000
#
# Epoch 00281: val_loss did not improve
# Epoch 282/3000
#
# Epoch 00282: val_loss did not improve
# Epoch 283/3000
#
# Epoch 00283: val_loss did not improve
# Epoch 284/3000
#
# Epoch 00284: val_loss did not improve
# Epoch 285/3000
#
# Epoch 00285: val_loss did not improve
# Epoch 286/3000
#
# Epoch 00286: val_loss did not improve
# Epoch 287/3000
#
# Epoch 00287: val_loss did not improve
# Epoch 288/3000
#
# Epoch 00288: val_loss did not improve
# Epoch 289/3000
#
# Epoch 00289: val_loss did not improve
# Epoch 290/3000
#
# Epoch 00290: val_loss did not improve
# Epoch 291/3000
#
# Epoch 00291: val_loss did not improve
# Epoch 292/3000
#
# Epoch 00292: val_loss did not improve
# Epoch 293/3000
#
# Epoch 00293: val_loss did not improve
# Epoch 294/3000
#
# Epoch 00294: val_loss did not improve
# Epoch 295/3000
#
# Epoch 00295: val_loss did not improve
# Epoch 296/3000
#
# Epoch 00296: val_loss did not improve
# Epoch 297/3000
#
# Epoch 00297: val_loss did not improve
# Epoch 298/3000
#
# Epoch 00298: val_loss did not improve
# Epoch 299/3000
#
# Epoch 00299: val_loss did not improve
# Epoch 300/3000
#
# Epoch 00300: val_loss did not improve
# Epoch 301/3000
#
# Epoch 00301: val_loss did not improve
# Epoch 302/3000
#
# Epoch 00302: val_loss did not improve
# Epoch 303/3000
#
# Epoch 00303: val_loss did not improve
# Epoch 304/3000
#
# Epoch 00304: val_loss did not improve
# Epoch 305/3000
#
# Epoch 00305: val_loss did not improve
# Epoch 306/3000
#
# Epoch 00306: val_loss did not improve
# Epoch 307/3000
#
# Epoch 00307: val_loss did not improve
# Epoch 308/3000
#
# Epoch 00308: val_loss did not improve
# Epoch 309/3000
#
# Epoch 00309: val_loss did not improve
# Epoch 310/3000
#
# Epoch 00310: val_loss did not improve
# Epoch 311/3000
#
# Epoch 00311: val_loss did not improve
# Epoch 312/3000
#
# Epoch 00312: val_loss did not improve
# Epoch 313/3000
#
# Epoch 00313: val_loss did not improve
# Epoch 314/3000
#
# Epoch 00314: val_loss did not improve
# Epoch 315/3000
#
# Epoch 00315: val_loss did not improve
# Epoch 316/3000
#
# Epoch 00316: val_loss did not improve
# Epoch 317/3000
#
# Epoch 00317: val_loss did not improve
# Epoch 318/3000
#
# Epoch 00318: val_loss did not improve
# Epoch 319/3000
#
# Epoch 00319: val_loss did not improve
# Epoch 320/3000
#
# Epoch 00320: val_loss did not improve
# Epoch 321/3000
#
# Epoch 00321: val_loss did not improve
# Epoch 322/3000
#
# Epoch 00322: val_loss did not improve
# Epoch 323/3000
#
# Epoch 00323: val_loss did not improve
# Epoch 324/3000
#
# Epoch 00324: val_loss did not improve
# Epoch 325/3000
#
# Epoch 00325: val_loss did not improve
# Epoch 326/3000
#
# Epoch 00326: val_loss did not improve
# Epoch 327/3000
#
# Epoch 00327: val_loss did not improve
# Epoch 328/3000
#
# Epoch 00328: val_loss did not improve
# Epoch 329/3000
#
# Epoch 00329: val_loss did not improve
# Epoch 330/3000
#
# Epoch 00330: val_loss did not improve
# Epoch 331/3000
#
# Epoch 00331: val_loss did not improve
# Epoch 332/3000
#
# Epoch 00332: val_loss did not improve
# Epoch 333/3000
#
# Epoch 00333: val_loss did not improve
# Epoch 334/3000
#
# Epoch 00334: val_loss did not improve
# Epoch 335/3000
#
# Epoch 00335: val_loss did not improve
# Epoch 336/3000
#
# Epoch 00336: val_loss did not improve
# Epoch 337/3000
#
# Epoch 00337: val_loss did not improve
# Epoch 338/3000
#
# Epoch 00338: val_loss did not improve
# Epoch 339/3000
#
# Epoch 00339: val_loss did not improve
# Epoch 340/3000
#
# Epoch 00340: val_loss did not improve
# Epoch 341/3000
#
# Epoch 00341: val_loss did not improve
# Epoch 342/3000
#
# Epoch 00342: val_loss did not improve
# Epoch 343/3000
#
# Epoch 00343: val_loss did not improve
# Epoch 344/3000
#
# Epoch 00344: val_loss did not improve
# Epoch 345/3000
#
# Epoch 00345: val_loss did not improve
# Epoch 346/3000
#
# Epoch 00346: val_loss did not improve
# Epoch 347/3000
#
# Epoch 00347: val_loss did not improve
# Epoch 348/3000
#
# Epoch 00348: val_loss did not improve
# Epoch 349/3000
#
# Epoch 00349: val_loss did not improve
# Epoch 350/3000
#
# Epoch 00350: val_loss did not improve
# Epoch 351/3000
#
# Epoch 00351: val_loss did not improve
# Epoch 352/3000
#
# Epoch 00352: val_loss did not improve
# Epoch 353/3000
#
# Epoch 00353: val_loss did not improve
# Epoch 354/3000
#
# Epoch 00354: val_loss did not improve
# Epoch 355/3000
#
# Epoch 00355: val_loss did not improve
# Epoch 356/3000
#
# Epoch 00356: val_loss did not improve
# Epoch 357/3000
#
# Epoch 00357: val_loss did not improve
# Epoch 358/3000
#
# Epoch 00358: val_loss did not improve
# Epoch 359/3000
#
# Epoch 00359: val_loss did not improve
# Epoch 360/3000
#
# Epoch 00360: val_loss did not improve
# Epoch 361/3000
#
# Epoch 00361: val_loss did not improve
# Epoch 362/3000
#
# Epoch 00362: val_loss did not improve
# Epoch 363/3000
#
# Epoch 00363: val_loss did not improve
# Epoch 364/3000
#
# Epoch 00364: val_loss did not improve
# Epoch 365/3000
#
# Epoch 00365: val_loss did not improve
# Epoch 366/3000
#
# Epoch 00366: val_loss did not improve
# Epoch 367/3000
#
# Epoch 00367: val_loss did not improve
# Epoch 368/3000
#
# Epoch 00368: val_loss did not improve
# Epoch 369/3000
#
# Epoch 00369: val_loss did not improve
# Epoch 370/3000
#
# Epoch 00370: val_loss did not improve
# Epoch 371/3000
#
# Epoch 00371: val_loss did not improve
# Epoch 372/3000
#
# Epoch 00372: val_loss did not improve
# Epoch 373/3000
#
# Epoch 00373: val_loss did not improve
# Epoch 374/3000
#
# Epoch 00374: val_loss did not improve
# Epoch 375/3000
#
# Epoch 00375: val_loss did not improve
# Epoch 376/3000
#
# Epoch 00376: val_loss did not improve
# Epoch 377/3000
#
# Epoch 00377: val_loss did not improve
# Epoch 378/3000
#
# Epoch 00378: val_loss did not improve
# Epoch 379/3000
#
# Epoch 00379: val_loss did not improve
# Epoch 380/3000
#
# Epoch 00380: val_loss did not improve
# Epoch 381/3000
#
# Epoch 00381: val_loss did not improve
# Epoch 382/3000
#
# Epoch 00382: val_loss did not improve
# Epoch 383/3000
#
# Epoch 00383: val_loss did not improve
# Epoch 384/3000
#
# Epoch 00384: val_loss did not improve
# Epoch 385/3000
#
# Epoch 00385: val_loss did not improve
# Epoch 386/3000
#
# Epoch 00386: val_loss did not improve
# Epoch 387/3000
#
# Epoch 00387: val_loss did not improve
# Epoch 388/3000
#
# Epoch 00388: val_loss did not improve
# Epoch 389/3000
#
# Epoch 00389: val_loss did not improve
# Epoch 390/3000
#
# Epoch 00390: val_loss did not improve
# Epoch 391/3000
#
# Epoch 00391: val_loss did not improve
# Epoch 392/3000
#
# Epoch 00392: val_loss did not improve
# Epoch 393/3000
#
# Epoch 00393: val_loss did not improve
# Epoch 394/3000
#
# Epoch 00394: val_loss did not improve
# Epoch 395/3000
#
# Epoch 00395: val_loss did not improve
# Epoch 396/3000
#
# Epoch 00396: val_loss did not improve
# Epoch 397/3000
#
# Epoch 00397: val_loss did not improve
# Epoch 398/3000
#
# Epoch 00398: val_loss did not improve
# Epoch 399/3000
#
# Epoch 00399: val_loss did not improve
# Epoch 400/3000
#
# Epoch 00400: val_loss did not improve
# Epoch 401/3000
#
# Epoch 00401: val_loss did not improve
# Epoch 402/3000
#
# Epoch 00402: val_loss did not improve
# Epoch 403/3000
#
# Epoch 00403: val_loss did not improve
# Epoch 404/3000
#
# Epoch 00404: val_loss did not improve
# Epoch 405/3000
#
# Epoch 00405: val_loss did not improve
# Epoch 406/3000
#
# Epoch 00406: val_loss did not improve
# Epoch 407/3000
#
# Epoch 00407: val_loss did not improve
# Epoch 408/3000
#
# Epoch 00408: val_loss did not improve
# Epoch 409/3000
#
# Epoch 00409: val_loss did not improve
# Epoch 410/3000
#
# Epoch 00410: val_loss did not improve
# Epoch 411/3000
#
# Epoch 00411: val_loss did not improve
# Epoch 412/3000
#
# Epoch 00412: val_loss did not improve
# Epoch 413/3000
#
# Epoch 00413: val_loss did not improve
# Epoch 414/3000
#
# Epoch 00414: val_loss did not improve
# Epoch 415/3000
#
# Epoch 00415: val_loss did not improve
# Epoch 416/3000
#
# Epoch 00416: val_loss did not improve
# Epoch 417/3000
#
# Epoch 00417: val_loss did not improve
# Epoch 418/3000
#
# Epoch 00418: val_loss did not improve
# Epoch 419/3000
#
# Epoch 00419: val_loss did not improve
# Epoch 420/3000
#
# Epoch 00420: val_loss did not improve
# Epoch 421/3000
#
# Epoch 00421: val_loss did not improve
# Epoch 422/3000
#
# Epoch 00422: val_loss did not improve
# Epoch 423/3000
#
# Epoch 00423: val_loss did not improve
# Epoch 424/3000
#
# Epoch 00424: val_loss did not improve
# Epoch 425/3000
#
# Epoch 00425: val_loss did not improve
# Epoch 426/3000
#
# Epoch 00426: val_loss did not improve
# Epoch 427/3000
#
# Epoch 00427: val_loss did not improve
# Epoch 428/3000
#
# Epoch 00428: val_loss did not improve
# Epoch 429/3000
#
# Epoch 00429: val_loss did not improve
# Epoch 430/3000
#
# Epoch 00430: val_loss did not improve
# Epoch 431/3000
#
# Epoch 00431: val_loss did not improve
# Epoch 432/3000
#
# Epoch 00432: val_loss did not improve
# Epoch 433/3000
#
# Epoch 00433: val_loss did not improve
# Epoch 434/3000
#
# Epoch 00434: val_loss did not improve
# Epoch 435/3000
#
# Epoch 00435: val_loss did not improve
# Epoch 436/3000
#
# Epoch 00436: val_loss did not improve
# Epoch 437/3000
#
# Epoch 00437: val_loss did not improve
# Epoch 438/3000
#
# Epoch 00438: val_loss did not improve
# Epoch 439/3000
#
# Epoch 00439: val_loss did not improve
# Epoch 440/3000
#
# Epoch 00440: val_loss did not improve
# Epoch 441/3000
#
# Epoch 00441: val_loss did not improve
# Epoch 442/3000
#
# Epoch 00442: val_loss did not improve
# Epoch 443/3000
#
# Epoch 00443: val_loss did not improve
# Epoch 444/3000
#
# Epoch 00444: val_loss did not improve
# Epoch 445/3000
#
# Epoch 00445: val_loss did not improve
# Epoch 446/3000
#
# Epoch 00446: val_loss did not improve
# Epoch 447/3000
#
# Epoch 00447: val_loss did not improve
# Epoch 448/3000
#
# Epoch 00448: val_loss did not improve
# Epoch 449/3000
#
# Epoch 00449: val_loss did not improve
# Epoch 450/3000
#
# Epoch 00450: val_loss did not improve
# Epoch 451/3000
#
# Epoch 00451: val_loss did not improve
# Epoch 452/3000
#
# Epoch 00452: val_loss did not improve
# Epoch 453/3000
#
# Epoch 00453: val_loss did not improve
# Epoch 454/3000
#
# Epoch 00454: val_loss did not improve
# Epoch 455/3000
#
# Epoch 00455: val_loss did not improve
# Epoch 456/3000
#
# Epoch 00456: val_loss did not improve
# Epoch 457/3000
#
# Epoch 00457: val_loss did not improve
# Epoch 458/3000
#
# Epoch 00458: val_loss did not improve
# Epoch 459/3000
#
# Epoch 00459: val_loss did not improve
# Epoch 460/3000
#
# Epoch 00460: val_loss did not improve
# Epoch 461/3000
#
# Epoch 00461: val_loss did not improve
# Epoch 462/3000
#
# Epoch 00462: val_loss did not improve
# Epoch 463/3000
#
# Epoch 00463: val_loss did not improve
# Epoch 464/3000
#
# Epoch 00464: val_loss did not improve
# Epoch 465/3000
#
# Epoch 00465: val_loss did not improve
# Epoch 466/3000
#
# Epoch 00466: val_loss did not improve
# Epoch 467/3000
#
# Epoch 00467: val_loss did not improve
# Epoch 468/3000
#
# Epoch 00468: val_loss did not improve
# Epoch 469/3000
#
# Epoch 00469: val_loss did not improve
# Epoch 470/3000
#
# Epoch 00470: val_loss did not improve
# Epoch 471/3000
#
# Epoch 00471: val_loss did not improve
# Epoch 472/3000
#
# Epoch 00472: val_loss did not improve
# Epoch 473/3000
#
# Epoch 00473: val_loss did not improve
# Epoch 474/3000
#
# Epoch 00474: val_loss did not improve
# Epoch 475/3000
#
# Epoch 00475: val_loss did not improve
# Epoch 476/3000
#
# Epoch 00476: val_loss did not improve
# Epoch 477/3000
#
# Epoch 00477: val_loss did not improve
# Epoch 478/3000
#
# Epoch 00478: val_loss did not improve
# Epoch 479/3000
#
# Epoch 00479: val_loss did not improve
# Epoch 480/3000
#
# Epoch 00480: val_loss did not improve
# Epoch 481/3000
#
# Epoch 00481: val_loss did not improve
# Epoch 482/3000
#
# Epoch 00482: val_loss did not improve
# Epoch 483/3000
#
# Epoch 00483: val_loss did not improve
# Epoch 484/3000
#
# Epoch 00484: val_loss did not improve
# Epoch 485/3000
#
# Epoch 00485: val_loss did not improve
# Epoch 486/3000
#
# Epoch 00486: val_loss did not improve
# Epoch 487/3000
#
# Epoch 00487: val_loss did not improve
# Epoch 488/3000
#
# Epoch 00488: val_loss did not improve
# Epoch 489/3000
#
# Epoch 00489: val_loss did not improve
# Epoch 490/3000
#
# Epoch 00490: val_loss did not improve
# Epoch 491/3000
#
# Epoch 00491: val_loss did not improve
# Epoch 492/3000
#
# Epoch 00492: val_loss did not improve
# Epoch 493/3000
#
# Epoch 00493: val_loss did not improve
# Epoch 494/3000
#
# Epoch 00494: val_loss did not improve
# Epoch 495/3000
#
# Epoch 00495: val_loss did not improve
# Epoch 496/3000
#
# Epoch 00496: val_loss did not improve
# Epoch 497/3000
#
# Epoch 00497: val_loss did not improve
# Epoch 498/3000
#
# Epoch 00498: val_loss did not improve
# Epoch 499/3000
#
# Epoch 00499: val_loss did not improve
# Epoch 500/3000
#
# Epoch 00500: val_loss did not improve
# Epoch 501/3000
#
# Epoch 00501: val_loss did not improve
# Epoch 502/3000
#
# Epoch 00502: val_loss did not improve
# Epoch 503/3000
#
# Epoch 00503: val_loss did not improve
# Epoch 504/3000
#
# Epoch 00504: val_loss did not improve
# Epoch 505/3000
#
# Epoch 00505: val_loss did not improve
# Epoch 506/3000
#
# Epoch 00506: val_loss did not improve
# Epoch 507/3000
#
# Epoch 00507: val_loss did not improve
# Epoch 508/3000
#
# Epoch 00508: val_loss did not improve
# Epoch 509/3000
#
# Epoch 00509: val_loss did not improve
# Epoch 510/3000
#
# Epoch 00510: val_loss did not improve
# Epoch 511/3000
#
# Epoch 00511: val_loss did not improve
# Epoch 512/3000
#
# Epoch 00512: val_loss did not improve
# Epoch 513/3000
#
# Epoch 00513: val_loss did not improve
# Epoch 514/3000
#
# Epoch 00514: val_loss did not improve
# Epoch 515/3000
#
# Epoch 00515: val_loss did not improve
# Epoch 516/3000
#
# Epoch 00516: val_loss did not improve
# Epoch 517/3000
#
# Epoch 00517: val_loss did not improve
# Epoch 518/3000
#
# Epoch 00518: val_loss did not improve
# Epoch 519/3000
#
# Epoch 00519: val_loss did not improve
# Epoch 520/3000
#
# Epoch 00520: val_loss did not improve
# Epoch 521/3000
#
# Epoch 00521: val_loss did not improve
# Epoch 522/3000
#
# Epoch 00522: val_loss did not improve
# Epoch 523/3000
#
# Epoch 00523: val_loss did not improve
# Epoch 524/3000
#
# Epoch 00524: val_loss did not improve
# Epoch 525/3000
#
# Epoch 00525: val_loss did not improve
# Epoch 526/3000
#
# Epoch 00526: val_loss did not improve
# Epoch 527/3000
#
# Epoch 00527: val_loss did not improve
# Epoch 528/3000
#
# Epoch 00528: val_loss did not improve
# Epoch 529/3000
#
# Epoch 00529: val_loss did not improve
# Epoch 530/3000
#
# Epoch 00530: val_loss did not improve
# Epoch 531/3000
#
# Epoch 00531: val_loss did not improve
# Epoch 532/3000
#
# Epoch 00532: val_loss did not improve
# Epoch 533/3000
#
# Epoch 00533: val_loss did not improve
# Epoch 534/3000
#
# Epoch 00534: val_loss did not improve
# Epoch 535/3000
#
# Epoch 00535: val_loss did not improve
# Epoch 536/3000
#
# Epoch 00536: val_loss did not improve
# Epoch 537/3000
#
# Epoch 00537: val_loss did not improve
# Epoch 538/3000
#
# Epoch 00538: val_loss did not improve
# Epoch 539/3000
#
# Epoch 00539: val_loss did not improve
# Epoch 540/3000
#
# Epoch 00540: val_loss did not improve
# Epoch 541/3000
#
# Epoch 00541: val_loss did not improve
# Epoch 542/3000
#
# Epoch 00542: val_loss did not improve
# Epoch 543/3000
#
# Epoch 00543: val_loss did not improve
# Epoch 544/3000
#
# Epoch 00544: val_loss did not improve
# Epoch 545/3000
#
# Epoch 00545: val_loss did not improve
# Epoch 546/3000
#
# Epoch 00546: val_loss did not improve
# Epoch 547/3000
#
# Epoch 00547: val_loss did not improve
# Epoch 548/3000
#
# Epoch 00548: val_loss did not improve
# Epoch 549/3000
#
# Epoch 00549: val_loss did not improve
# Epoch 550/3000
#
# Epoch 00550: val_loss did not improve
# Epoch 551/3000
#
# Epoch 00551: val_loss did not improve
# Epoch 552/3000
#
# Epoch 00552: val_loss did not improve
# Epoch 553/3000
#
# Epoch 00553: val_loss did not improve
# Epoch 554/3000
#
# Epoch 00554: val_loss did not improve
# Epoch 555/3000
#
# Epoch 00555: val_loss did not improve
# Epoch 556/3000
#
# Epoch 00556: val_loss did not improve
# Epoch 557/3000
#
# Epoch 00557: val_loss did not improve
# Epoch 558/3000
#
# Epoch 00558: val_loss did not improve
# Epoch 559/3000
#
# Epoch 00559: val_loss did not improve
# Epoch 560/3000
#
# Epoch 00560: val_loss did not improve
# Epoch 561/3000
#
# Epoch 00561: val_loss did not improve
# Epoch 562/3000
#
# Epoch 00562: val_loss did not improve
# Epoch 563/3000
#
# Epoch 00563: val_loss did not improve
# Epoch 564/3000
#
# Epoch 00564: val_loss did not improve
# Epoch 565/3000
#
# Epoch 00565: val_loss did not improve
# Epoch 566/3000
#
# Epoch 00566: val_loss did not improve
# Epoch 567/3000
#
# Epoch 00567: val_loss did not improve
# Epoch 568/3000
#
# Epoch 00568: val_loss did not improve
# Epoch 569/3000
#
# Epoch 00569: val_loss did not improve
# Epoch 570/3000
#
# Epoch 00570: val_loss did not improve
# Epoch 571/3000
#
# Epoch 00571: val_loss did not improve
# Epoch 572/3000
#
# Epoch 00572: val_loss did not improve
# Epoch 573/3000
#
# Epoch 00573: val_loss did not improve
# Epoch 574/3000
#
# Epoch 00574: val_loss did not improve
# Epoch 575/3000
#
# Epoch 00575: val_loss did not improve
# Epoch 576/3000
#
# Epoch 00576: val_loss did not improve
# Epoch 577/3000
#
# Epoch 00577: val_loss did not improve
# Epoch 578/3000
#
# Epoch 00578: val_loss did not improve
# Epoch 579/3000
#
# Epoch 00579: val_loss did not improve
# Epoch 580/3000
#
# Epoch 00580: val_loss did not improve
# Epoch 581/3000
#
# Epoch 00581: val_loss did not improve
# Epoch 582/3000
#
# Epoch 00582: val_loss did not improve
# Epoch 583/3000
#
# Epoch 00583: val_loss did not improve
# Epoch 584/3000
#
# Epoch 00584: val_loss did not improve
# Epoch 585/3000
#
# Epoch 00585: val_loss did not improve
# Epoch 586/3000
#
# Epoch 00586: val_loss did not improve
# Epoch 587/3000
#
# Epoch 00587: val_loss did not improve
# Epoch 588/3000
#
# Epoch 00588: val_loss did not improve
# Epoch 589/3000
#
# Epoch 00589: val_loss did not improve
# Epoch 590/3000
#
# Epoch 00590: val_loss did not improve
# Epoch 591/3000
#
# Epoch 00591: val_loss did not improve
# Epoch 592/3000
#
# Epoch 00592: val_loss did not improve
# Epoch 593/3000
#
# Epoch 00593: val_loss did not improve
# Epoch 594/3000
#
# Epoch 00594: val_loss did not improve
# Epoch 595/3000
#
# Epoch 00595: val_loss did not improve
# Epoch 596/3000
#
# Epoch 00596: val_loss did not improve
# Epoch 597/3000
#
# Epoch 00597: val_loss did not improve
# Epoch 598/3000
#
# Epoch 00598: val_loss did not improve
# Epoch 599/3000
#
# Epoch 00599: val_loss did not improve
# Epoch 600/3000
#
# Epoch 00600: val_loss did not improve
# Epoch 601/3000
#
# Epoch 00601: val_loss did not improve
# Epoch 602/3000
#
# Epoch 00602: val_loss did not improve
# Epoch 603/3000
#
# Epoch 00603: val_loss did not improve
# Epoch 604/3000
#
# Epoch 00604: val_loss did not improve
# Epoch 605/3000
#
# Epoch 00605: val_loss did not improve
# Epoch 606/3000
#
# Epoch 00606: val_loss did not improve
# Epoch 607/3000
#
# Epoch 00607: val_loss did not improve
# Epoch 608/3000
#
# Epoch 00608: val_loss did not improve
# Epoch 609/3000
#
# Epoch 00609: val_loss did not improve
# Epoch 610/3000
#
# Epoch 00610: val_loss did not improve
# Epoch 611/3000
#
# Epoch 00611: val_loss did not improve
# Epoch 612/3000
#
# Epoch 00612: val_loss did not improve
# Epoch 613/3000
#
# Epoch 00613: val_loss did not improve
# Epoch 614/3000
#
# Epoch 00614: val_loss did not improve
# Epoch 615/3000
#
# Epoch 00615: val_loss did not improve
# Epoch 616/3000
#
# Epoch 00616: val_loss did not improve
# Epoch 617/3000
#
# Epoch 00617: val_loss did not improve
# Epoch 618/3000
#
# Epoch 00618: val_loss did not improve
# Epoch 619/3000
#
# Epoch 00619: val_loss did not improve
# Epoch 620/3000
#
# Epoch 00620: val_loss did not improve
# Epoch 621/3000
#
# Epoch 00621: val_loss did not improve
# Epoch 622/3000
#
# Epoch 00622: val_loss did not improve
# Epoch 623/3000
#
# Epoch 00623: val_loss did not improve
# Epoch 624/3000
#
# Epoch 00624: val_loss did not improve
# Epoch 625/3000
#
# Epoch 00625: val_loss did not improve
# Epoch 626/3000
#
# Epoch 00626: val_loss did not improve
# Epoch 627/3000
#
# Epoch 00627: val_loss did not improve
# Epoch 628/3000
#
# Epoch 00628: val_loss did not improve
# Epoch 629/3000
#
# Epoch 00629: val_loss did not improve
# Epoch 630/3000
#
# Epoch 00630: val_loss did not improve
# Epoch 631/3000
#
# Epoch 00631: val_loss did not improve
# Epoch 632/3000
#
# Epoch 00632: val_loss did not improve
# Epoch 633/3000
#
# Epoch 00633: val_loss did not improve
# Epoch 634/3000
#
# Epoch 00634: val_loss did not improve
# Epoch 635/3000
#
# Epoch 00635: val_loss did not improve
# Epoch 636/3000
#
# Epoch 00636: val_loss did not improve
# Epoch 637/3000
#
# Epoch 00637: val_loss did not improve
# Epoch 638/3000
#
# Epoch 00638: val_loss did not improve
# Epoch 639/3000
#
# Epoch 00639: val_loss did not improve
# Epoch 640/3000
#
# Epoch 00640: val_loss did not improve
# Epoch 641/3000
#
# Epoch 00641: val_loss did not improve
# Epoch 642/3000
#
# Epoch 00642: val_loss did not improve
# Epoch 643/3000
#
# Epoch 00643: val_loss did not improve
# Epoch 644/3000
#
# Epoch 00644: val_loss did not improve
# Epoch 645/3000
#
# Epoch 00645: val_loss did not improve
# Epoch 646/3000
#
# Epoch 00646: val_loss did not improve
# Epoch 647/3000
#
# Epoch 00647: val_loss did not improve
# Epoch 648/3000
#
# Epoch 00648: val_loss did not improve
# Epoch 649/3000
#
# Epoch 00649: val_loss did not improve
# Epoch 650/3000
#
# Epoch 00650: val_loss did not improve
# Epoch 651/3000
#
# Epoch 00651: val_loss did not improve
# Epoch 652/3000
#
# Epoch 00652: val_loss did not improve
# Epoch 653/3000
#
# Epoch 00653: val_loss did not improve
# Epoch 654/3000
#
# Epoch 00654: val_loss did not improve
# Epoch 655/3000
#
# Epoch 00655: val_loss did not improve
# Epoch 656/3000
#
# Epoch 00656: val_loss did not improve
# Epoch 657/3000
#
# Epoch 00657: val_loss did not improve
# Epoch 658/3000
#
# Epoch 00658: val_loss did not improve
# Epoch 659/3000
#
# Epoch 00659: val_loss did not improve
# Epoch 660/3000
#
# Epoch 00660: val_loss did not improve
# Epoch 661/3000
#
# Epoch 00661: val_loss did not improve
# Epoch 662/3000
#
# Epoch 00662: val_loss did not improve
# Epoch 663/3000
#
# Epoch 00663: val_loss did not improve
# Epoch 664/3000
#
# Epoch 00664: val_loss did not improve
# Epoch 665/3000
#
# Epoch 00665: val_loss did not improve
# Epoch 666/3000
#
# Epoch 00666: val_loss did not improve
# Epoch 667/3000
#
# Epoch 00667: val_loss did not improve
# Epoch 668/3000
#
# Epoch 00668: val_loss did not improve
# Epoch 669/3000
#
# Epoch 00669: val_loss did not improve
# Epoch 670/3000
#
# Epoch 00670: val_loss did not improve
# Epoch 671/3000
#
# Epoch 00671: val_loss did not improve
# Epoch 672/3000
#
# Epoch 00672: val_loss did not improve
# Epoch 673/3000
#
# Epoch 00673: val_loss did not improve
# Epoch 674/3000
#
# Epoch 00674: val_loss did not improve
# Epoch 675/3000
#
# Epoch 00675: val_loss did not improve
# Epoch 676/3000
#
# Epoch 00676: val_loss did not improve
# Epoch 677/3000
#
# Epoch 00677: val_loss did not improve
# Epoch 678/3000
#
# Epoch 00678: val_loss did not improve
# Epoch 679/3000
#
# Epoch 00679: val_loss did not improve
# Epoch 680/3000
#
# Epoch 00680: val_loss did not improve
# Epoch 681/3000
#
# Epoch 00681: val_loss did not improve
# Epoch 682/3000
#
# Epoch 00682: val_loss did not improve
# Epoch 683/3000
#
# Epoch 00683: val_loss did not improve
# Epoch 684/3000
#
# Epoch 00684: val_loss did not improve
# Epoch 685/3000
#
# Epoch 00685: val_loss did not improve
# Epoch 686/3000
#
# Epoch 00686: val_loss did not improve
# Epoch 687/3000
#
# Epoch 00687: val_loss did not improve
# Epoch 688/3000
#
# Epoch 00688: val_loss did not improve
# Epoch 689/3000
#
# Epoch 00689: val_loss did not improve
# Epoch 690/3000
#
# ...
#
# Epoch 02710: val_loss did not improve
# Epoch 2711/3000
#
# Epoch 02711: val_loss did not improve
# Epoch 2712/3000
#
# Epoch 02712: val_loss did not improve
# Epoch 2713/3000
#
# Epoch 02713: val_loss did not improve
# Epoch 2714/3000
#
# Epoch 02714: val_loss did not improve
# Epoch 2715/3000
#
# Epoch 02715: val_loss did not improve
# Epoch 2716/3000
#
# Epoch 02716: val_loss did not improve
# Epoch 2717/3000
#
# Epoch 02717: val_loss did not improve
# Epoch 2718/3000
#
# Epoch 02718: val_loss did not improve
# Epoch 2719/3000
#
# Epoch 02719: val_loss did not improve
# Epoch 2720/3000
#
# Epoch 02720: val_loss did not improve
# Epoch 2721/3000
#
# Epoch 02721: val_loss did not improve
# Epoch 2722/3000
#
# Epoch 02722: val_loss did not improve
# Epoch 2723/3000
#
# Epoch 02723: val_loss did not improve
# Epoch 2724/3000
#
# Epoch 02724: val_loss did not improve
# Epoch 2725/3000
#
# Epoch 02725: val_loss did not improve
# Epoch 2726/3000
#
# Epoch 02726: val_loss did not improve
# Epoch 2727/3000
#
# Epoch 02727: val_loss did not improve
# Epoch 2728/3000
#
# Epoch 02728: val_loss did not improve
# Epoch 2729/3000
#
# Epoch 02729: val_loss did not improve
# Epoch 2730/3000
#
# Epoch 02730: val_loss did not improve
# Epoch 2731/3000
#
# Epoch 02731: val_loss did not improve
# Epoch 2732/3000
#
# Epoch 02732: val_loss did not improve
# Epoch 2733/3000
#
# Epoch 02733: val_loss did not improve
# Epoch 2734/3000
#
# Epoch 02734: val_loss did not improve
# Epoch 2735/3000
#
# Epoch 02735: val_loss did not improve
# Epoch 2736/3000
#
# Epoch 02736: val_loss did not improve
# Epoch 2737/3000
#
# Epoch 02737: val_loss did not improve
# Epoch 2738/3000
#
# Epoch 02738: val_loss did not improve
# Epoch 2739/3000
#
# Epoch 02739: val_loss did not improve
# Epoch 2740/3000
#
# Epoch 02740: val_loss did not improve
# Epoch 2741/3000
#
# Epoch 02741: val_loss did not improve
# Epoch 2742/3000
#
# Epoch 02742: val_loss did not improve
# Epoch 2743/3000
#
# Epoch 02743: val_loss did not improve
# Epoch 2744/3000
#
# Epoch 02744: val_loss did not improve
# Epoch 2745/3000
#
# Epoch 02745: val_loss did not improve
# Epoch 2746/3000
#
# Epoch 02746: val_loss did not improve
# Epoch 2747/3000
#
# Epoch 02747: val_loss did not improve
# Epoch 2748/3000
#
# Epoch 02748: val_loss did not improve
# Epoch 2749/3000
#
# Epoch 02749: val_loss did not improve
# Epoch 2750/3000
#
# Epoch 02750: val_loss did not improve
# Epoch 2751/3000
#
# Epoch 02751: val_loss did not improve
# Epoch 2752/3000
#
# Epoch 02752: val_loss did not improve
# Epoch 2753/3000
#
# Epoch 02753: val_loss did not improve
# Epoch 2754/3000
#
# Epoch 02754: val_loss did not improve
# Epoch 2755/3000
#
# Epoch 02755: val_loss did not improve
# Epoch 2756/3000
#
# Epoch 02756: val_loss did not improve
# Epoch 2757/3000
#
# Epoch 02757: val_loss did not improve
# Epoch 2758/3000
#
# Epoch 02758: val_loss did not improve
# Epoch 2759/3000
#
# Epoch 02759: val_loss did not improve
# Epoch 2760/3000
#
# Epoch 02760: val_loss did not improve
# Epoch 2761/3000
#
# Epoch 02761: val_loss did not improve
# Epoch 2762/3000
#
# Epoch 02762: val_loss did not improve
# Epoch 2763/3000
#
# Epoch 02763: val_loss did not improve
# Epoch 2764/3000
#
# Epoch 02764: val_loss did not improve
# Epoch 2765/3000
#
# Epoch 02765: val_loss did not improve
# Epoch 2766/3000
#
# Epoch 02766: val_loss did not improve
# Epoch 2767/3000
#
# Epoch 02767: val_loss did not improve
# Epoch 2768/3000
#
# Epoch 02768: val_loss did not improve
# Epoch 2769/3000
#
# Epoch 02769: val_loss did not improve
# Epoch 2770/3000
#
# Epoch 02770: val_loss did not improve
# Epoch 2771/3000
#
# Epoch 02771: val_loss did not improve
# Epoch 2772/3000
#
# Epoch 02772: val_loss did not improve
# Epoch 2773/3000
#
# Epoch 02773: val_loss did not improve
# Epoch 2774/3000
#
# Epoch 02774: val_loss did not improve
# Epoch 2775/3000
#
# Epoch 02775: val_loss did not improve
# Epoch 2776/3000
#
# Epoch 02776: val_loss did not improve
# Epoch 2777/3000
#
# Epoch 02777: val_loss did not improve
# Epoch 2778/3000
#
# Epoch 02778: val_loss did not improve
# Epoch 2779/3000
#
# Epoch 02779: val_loss did not improve
# Epoch 2780/3000
#
# Epoch 02780: val_loss did not improve
# Epoch 2781/3000
#
# Epoch 02781: val_loss did not improve
# Epoch 2782/3000
#
# Epoch 02782: val_loss did not improve
# Epoch 2783/3000
#
# Epoch 02783: val_loss did not improve
# Epoch 2784/3000
#
# Epoch 02784: val_loss did not improve
# Epoch 2785/3000
#
# Epoch 02785: val_loss did not improve
# Epoch 2786/3000
#
# Epoch 02786: val_loss did not improve
# Epoch 2787/3000
#
# Epoch 02787: val_loss did not improve
# Epoch 2788/3000
#
# Epoch 02788: val_loss did not improve
# Epoch 2789/3000
#
# Epoch 02789: val_loss did not improve
# Epoch 2790/3000
#
# Epoch 02790: val_loss did not improve
# Epoch 2791/3000
#
# Epoch 02791: val_loss did not improve
# Epoch 2792/3000
#
# Epoch 02792: val_loss did not improve
# Epoch 2793/3000
#
# Epoch 02793: val_loss did not improve
# Epoch 2794/3000
#
# Epoch 02794: val_loss did not improve
# Epoch 2795/3000
#
# Epoch 02795: val_loss did not improve
# Epoch 2796/3000
#
# Epoch 02796: val_loss did not improve
# Epoch 2797/3000
#
# Epoch 02797: val_loss did not improve
# Epoch 2798/3000
#
# Epoch 02798: val_loss did not improve
# Epoch 2799/3000
#
# Epoch 02799: val_loss did not improve
# Epoch 2800/3000
#
# Epoch 02800: val_loss did not improve
# Epoch 2801/3000
#
# Epoch 02801: val_loss did not improve
# Epoch 2802/3000
#
# Epoch 02802: val_loss did not improve
# Epoch 2803/3000
#
# Epoch 02803: val_loss did not improve
# Epoch 2804/3000
#
# Epoch 02804: val_loss did not improve
# Epoch 2805/3000
#
# Epoch 02805: val_loss did not improve
# Epoch 2806/3000
#
# Epoch 02806: val_loss did not improve
# Epoch 2807/3000
#
# Epoch 02807: val_loss did not improve
# Epoch 2808/3000
#
# Epoch 02808: val_loss did not improve
# Epoch 2809/3000
#
# Epoch 02809: val_loss did not improve
# Epoch 2810/3000
#
# Epoch 02810: val_loss did not improve
# Epoch 2811/3000
#
# Epoch 02811: val_loss did not improve
# Epoch 2812/3000
#
# Epoch 02812: val_loss did not improve
# Epoch 2813/3000
#
# Epoch 02813: val_loss did not improve
# Epoch 2814/3000
#
# Epoch 02814: val_loss did not improve
# Epoch 2815/3000
#
# Epoch 02815: val_loss did not improve
# Epoch 2816/3000
#
# Epoch 02816: val_loss did not improve
# Epoch 2817/3000
#
# Epoch 02817: val_loss did not improve
# Epoch 2818/3000
#
# Epoch 02818: val_loss did not improve
# Epoch 2819/3000
#
# Epoch 02819: val_loss did not improve
# Epoch 2820/3000
#
# Epoch 02820: val_loss did not improve
# Epoch 2821/3000
#
# Epoch 02821: val_loss did not improve
# Epoch 2822/3000
#
# Epoch 02822: val_loss did not improve
# Epoch 2823/3000
#
# Epoch 02823: val_loss did not improve
# Epoch 2824/3000
#
# Epoch 02824: val_loss did not improve
# Epoch 2825/3000
#
# Epoch 02825: val_loss did not improve
# Epoch 2826/3000
#
# Epoch 02826: val_loss did not improve
# Epoch 2827/3000
#
# Epoch 02827: val_loss did not improve
# Epoch 2828/3000
#
# Epoch 02828: val_loss did not improve
# Epoch 2829/3000
#
# Epoch 02829: val_loss did not improve
# Epoch 2830/3000
#
# Epoch 02830: val_loss did not improve
# Epoch 2831/3000
#
# Epoch 02831: val_loss did not improve
# Epoch 2832/3000
#
# Epoch 02832: val_loss did not improve
# Epoch 2833/3000
#
# Epoch 02833: val_loss did not improve
# Epoch 2834/3000
#
# Epoch 02834: val_loss did not improve
# Epoch 2835/3000
#
# Epoch 02835: val_loss did not improve
# Epoch 2836/3000
#
# Epoch 02836: val_loss did not improve
# Epoch 2837/3000
#
# Epoch 02837: val_loss did not improve
# Epoch 2838/3000
#
# Epoch 02838: val_loss did not improve
# Epoch 2839/3000
#
# Epoch 02839: val_loss did not improve
# Epoch 2840/3000
#
# Epoch 02840: val_loss did not improve
# Epoch 2841/3000
#
# Epoch 02841: val_loss did not improve
# Epoch 2842/3000
#
# Epoch 02842: val_loss did not improve
# Epoch 2843/3000
#
# Epoch 02843: val_loss did not improve
# Epoch 2844/3000
#
# Epoch 02844: val_loss did not improve
# Epoch 2845/3000
#
# Epoch 02845: val_loss did not improve
# Epoch 2846/3000
#
# Epoch 02846: val_loss did not improve
# Epoch 2847/3000
#
# Epoch 02847: val_loss did not improve
# Epoch 2848/3000
#
# Epoch 02848: val_loss did not improve
# Epoch 2849/3000
#
# Epoch 02849: val_loss did not improve
# Epoch 2850/3000
#
# Epoch 02850: val_loss did not improve
# Epoch 2851/3000
#
# Epoch 02851: val_loss did not improve
# Epoch 2852/3000
#
# Epoch 02852: val_loss did not improve
# Epoch 2853/3000
#
# Epoch 02853: val_loss did not improve
# Epoch 2854/3000
#
# Epoch 02854: val_loss did not improve
# Epoch 2855/3000
#
# Epoch 02855: val_loss did not improve
# Epoch 2856/3000
#
# Epoch 02856: val_loss did not improve
# Epoch 2857/3000
#
# Epoch 02857: val_loss did not improve
# Epoch 2858/3000
#
# Epoch 02858: val_loss did not improve
# Epoch 2859/3000
#
# Epoch 02859: val_loss did not improve
# Epoch 2860/3000
#
# Epoch 02860: val_loss did not improve
# Epoch 2861/3000
#
# Epoch 02861: val_loss did not improve
# Epoch 2862/3000
#
# Epoch 02862: val_loss did not improve
# Epoch 2863/3000
#
# Epoch 02863: val_loss did not improve
# Epoch 2864/3000
#
# Epoch 02864: val_loss did not improve
# Epoch 2865/3000
#
# Epoch 02865: val_loss did not improve
# Epoch 2866/3000
#
# Epoch 02866: val_loss did not improve
# Epoch 2867/3000
#
# Epoch 02867: val_loss did not improve
# Epoch 2868/3000
#
# Epoch 02868: val_loss did not improve
# Epoch 2869/3000
#
# Epoch 02869: val_loss did not improve
# Epoch 2870/3000
#
# Epoch 02870: val_loss did not improve
# Epoch 2871/3000
#
# Epoch 02871: val_loss did not improve
# Epoch 2872/3000
#
# Epoch 02872: val_loss did not improve
# Epoch 2873/3000
#
# Epoch 02873: val_loss did not improve
# Epoch 2874/3000
#
# Epoch 02874: val_loss did not improve
# Epoch 2875/3000
#
# Epoch 02875: val_loss did not improve
# Epoch 2876/3000
#
# Epoch 02876: val_loss did not improve
# Epoch 2877/3000
#
# Epoch 02877: val_loss did not improve
# Epoch 2878/3000
#
# Epoch 02878: val_loss did not improve
# Epoch 2879/3000
#
# Epoch 02879: val_loss did not improve
# Epoch 2880/3000
#
# Epoch 02880: val_loss did not improve
# Epoch 2881/3000
#
# Epoch 02881: val_loss did not improve
# Epoch 2882/3000
#
# Epoch 02882: val_loss did not improve
# Epoch 2883/3000
#
# Epoch 02883: val_loss did not improve
# Epoch 2884/3000
#
# Epoch 02884: val_loss did not improve
# Epoch 2885/3000
#
# Epoch 02885: val_loss did not improve
# Epoch 2886/3000
#
# Epoch 02886: val_loss did not improve
# Epoch 2887/3000
#
# Epoch 02887: val_loss did not improve
# Epoch 2888/3000
#
# Epoch 02888: val_loss did not improve
# Epoch 2889/3000
#
# Epoch 02889: val_loss did not improve
# Epoch 2890/3000
#
# Epoch 02890: val_loss did not improve
# Epoch 2891/3000
#
# Epoch 02891: val_loss did not improve
# Epoch 2892/3000
#
# Epoch 02892: val_loss did not improve
# Epoch 2893/3000
#
# Epoch 02893: val_loss did not improve
# Epoch 2894/3000
#
# Epoch 02894: val_loss did not improve
# Epoch 2895/3000
#
# Epoch 02895: val_loss did not improve
# Epoch 2896/3000
#
# Epoch 02896: val_loss did not improve
# Epoch 2897/3000
#
# Epoch 02897: val_loss did not improve
# Epoch 2898/3000
#
# Epoch 02898: val_loss did not improve
# Epoch 2899/3000
#
# Epoch 02899: val_loss did not improve
# Epoch 2900/3000
#
# Epoch 02900: val_loss did not improve
# Epoch 2901/3000
#
# Epoch 02901: val_loss did not improve
# Epoch 2902/3000
#
# Epoch 02902: val_loss did not improve
# Epoch 2903/3000
#
# Epoch 02903: val_loss did not improve
# Epoch 2904/3000
#
# Epoch 02904: val_loss did not improve
# Epoch 2905/3000
#
# Epoch 02905: val_loss did not improve
# Epoch 2906/3000
#
# Epoch 02906: val_loss did not improve
# Epoch 2907/3000
#
# Epoch 02907: val_loss did not improve
# Epoch 2908/3000
#
# Epoch 02908: val_loss did not improve
# Epoch 2909/3000
#
# Epoch 02909: val_loss did not improve
# Epoch 2910/3000
#
# Epoch 02910: val_loss did not improve
# Epoch 2911/3000
#
# Epoch 02911: val_loss did not improve
# Epoch 2912/3000
#
# Epoch 02912: val_loss did not improve
# Epoch 2913/3000
#
# Epoch 02913: val_loss did not improve
# Epoch 2914/3000
#
# Epoch 02914: val_loss did not improve
# Epoch 2915/3000
#
# Epoch 02915: val_loss did not improve
# Epoch 2916/3000
#
# Epoch 02916: val_loss did not improve
# Epoch 2917/3000
#
# Epoch 02917: val_loss did not improve
# Epoch 2918/3000
#
# Epoch 02918: val_loss did not improve
# Epoch 2919/3000
#
# Epoch 02919: val_loss did not improve
# Epoch 2920/3000
#
# Epoch 02920: val_loss did not improve
# Epoch 2921/3000
#
# Epoch 02921: val_loss did not improve
# Epoch 2922/3000
#
# Epoch 02922: val_loss did not improve
# Epoch 2923/3000
#
# Epoch 02923: val_loss did not improve
# Epoch 2924/3000
#
# Epoch 02924: val_loss did not improve
# Epoch 2925/3000
#
# Epoch 02925: val_loss did not improve
# Epoch 2926/3000
#
# Epoch 02926: val_loss did not improve
# Epoch 2927/3000
#
# Epoch 02927: val_loss did not improve
# Epoch 2928/3000
#
# Epoch 02928: val_loss did not improve
# Epoch 2929/3000
#
# Epoch 02929: val_loss did not improve
# Epoch 2930/3000
#
# Epoch 02930: val_loss did not improve
# Epoch 2931/3000
#
# Epoch 02931: val_loss did not improve
# Epoch 2932/3000
#
# Epoch 02932: val_loss did not improve
# Epoch 2933/3000
#
# Epoch 02933: val_loss did not improve
# Epoch 2934/3000
#
# Epoch 02934: val_loss did not improve
# Epoch 2935/3000
#
# Epoch 02935: val_loss did not improve
# Epoch 2936/3000
#
# Epoch 02936: val_loss did not improve
# Epoch 2937/3000
#
# Epoch 02937: val_loss did not improve
# Epoch 2938/3000
#
# Epoch 02938: val_loss did not improve
# Epoch 2939/3000
#
# Epoch 02939: val_loss did not improve
# Epoch 2940/3000
#
# Epoch 02940: val_loss did not improve
# Epoch 2941/3000
#
# Epoch 02941: val_loss did not improve
# Epoch 2942/3000
#
# Epoch 02942: val_loss did not improve
# Epoch 2943/3000
#
# Epoch 02943: val_loss did not improve
# Epoch 2944/3000
#
# Epoch 02944: val_loss did not improve
# Epoch 2945/3000
#
# Epoch 02945: val_loss did not improve
# Epoch 2946/3000
#
# Epoch 02946: val_loss did not improve
# Epoch 2947/3000
#
# Epoch 02947: val_loss did not improve
# Epoch 2948/3000
#
# Epoch 02948: val_loss did not improve
# Epoch 2949/3000
#
# Epoch 02949: val_loss did not improve
# Epoch 2950/3000
#
# Epoch 02950: val_loss did not improve
# Epoch 2951/3000
#
# Epoch 02951: val_loss did not improve
# Epoch 2952/3000
#
# Epoch 02952: val_loss did not improve
# Epoch 2953/3000
#
# Epoch 02953: val_loss did not improve
# Epoch 2954/3000
#
# Epoch 02954: val_loss did not improve
# Epoch 2955/3000
#
# Epoch 02955: val_loss did not improve
# Epoch 2956/3000
#
# Epoch 02956: val_loss did not improve
# Epoch 2957/3000
#
# Epoch 02957: val_loss did not improve
# Epoch 2958/3000
#
# Epoch 02958: val_loss did not improve
# Epoch 2959/3000
#
# Epoch 02959: val_loss did not improve
# Epoch 2960/3000
#
# Epoch 02960: val_loss did not improve
# Epoch 2961/3000
#
# Epoch 02961: val_loss did not improve
# Epoch 2962/3000
#
# Epoch 02962: val_loss did not improve
# Epoch 2963/3000
#
# Epoch 02963: val_loss did not improve
# Epoch 2964/3000
#
# Epoch 02964: val_loss did not improve
# Epoch 2965/3000
#
# Epoch 02965: val_loss did not improve
# Epoch 2966/3000
#
# Epoch 02966: val_loss did not improve
# Epoch 2967/3000
#
# Epoch 02967: val_loss did not improve
# Epoch 2968/3000
#
# Epoch 02968: val_loss did not improve
# Epoch 2969/3000
#
# Epoch 02969: val_loss did not improve
# Epoch 2970/3000
#
# Epoch 02970: val_loss did not improve
# Epoch 2971/3000
#
# Epoch 02971: val_loss did not improve
# Epoch 2972/3000
#
# Epoch 02972: val_loss did not improve
# Epoch 2973/3000
#
# Epoch 02973: val_loss did not improve
# Epoch 2974/3000
#
# Epoch 02974: val_loss did not improve
# Epoch 2975/3000
#
# Epoch 02975: val_loss did not improve
# Epoch 2976/3000
#
# Epoch 02976: val_loss did not improve
# Epoch 2977/3000
#
# Epoch 02977: val_loss did not improve
# Epoch 2978/3000
#
# Epoch 02978: val_loss did not improve
# Epoch 2979/3000
#
# Epoch 02979: val_loss did not improve
# Epoch 2980/3000
#
# Epoch 02980: val_loss did not improve
# Epoch 2981/3000
#
# Epoch 02981: val_loss did not improve
# Epoch 2982/3000
#
# Epoch 02982: val_loss did not improve
# Epoch 2983/3000
#
# Epoch 02983: val_loss did not improve
# Epoch 2984/3000
#
# Epoch 02984: val_loss did not improve
# Epoch 2985/3000
#
# Epoch 02985: val_loss did not improve
# Epoch 2986/3000
#
# Epoch 02986: val_loss did not improve
# Epoch 2987/3000
#
# Epoch 02987: val_loss did not improve
# Epoch 2988/3000
#
# Epoch 02988: val_loss did not improve
# Epoch 2989/3000
#
# Epoch 02989: val_loss did not improve
# Epoch 2990/3000
#
# Epoch 02990: val_loss did not improve
# Epoch 2991/3000
#
# Epoch 02991: val_loss did not improve
# Epoch 2992/3000
#
# Epoch 02992: val_loss did not improve
# Epoch 2993/3000
#
# Epoch 02993: val_loss did not improve
# Epoch 2994/3000
#
# Epoch 02994: val_loss did not improve
# Epoch 2995/3000
#
# Epoch 02995: val_loss did not improve
# Epoch 2996/3000
#
# Epoch 02996: val_loss did not improve
# Epoch 2997/3000
#
# Epoch 02997: val_loss did not improve
# Epoch 2998/3000
#
# Epoch 02998: val_loss did not improve
# Epoch 2999/3000
#
# Epoch 02999: val_loss did not improve
# Epoch 3000/3000
#
# Epoch 03000: val_loss did not improve

# %%
all_files = os.listdir(dir_name)
all_files.sort()
weights_file = all_files[-1]

# %%
weights_file = 'single-model-990.h5'

# %%
model.load_weights(dir_name+"/"+weights_file)

# %%
test_x[0].sum()
# Out:
# 511.58536

# %%
pred_train = model.predict([train_x,train_temp])
pred_v = model.predict([v_x,v_temp])
pred_test = model.predict([test_x,test_temp])

# %%
train_cost = relative_cost(train_y,pred_train)
v_cost = relative_cost(v_y,pred_v)
test_cost = relative_cost(test_y,pred_test)

# %%
train_cost,test_cost,v_cost
# Out:
# (1.0024222, 1.0602078, 1.0384086)

# %%
train_cost = mse(train_y,pred_train)
v_cost = mse(v_y,pred_v)
test_cost = mse(test_y,pred_test)

# %%
train_cost,test_cost,v_cost
# Out:
# (188.09634, 200.57707, 248.31352)

# %%
model.save_weights("WOrking model with temp.h5")

# %%
plt.close('all')
plt.plot(np.arange(672),model.predict([test_x,test_temp])[21])
plt.plot(np.arange(672),test_y[21])
plt.title("Degree Days Prediction")
plt.ylim([0,3.5])
plt.show()

# %%
relative_cost(test_y[21],model.predict([test_x,test_temp])[21])
# Out:
# 0.80985785

# %%
relative_cost(test_y[0:3],model.predict(test_x)[0:3])
# Out:
# 1.1072702

# %%
train_cost = ((train_y - pred_train) ** 2).mean()
v_cost =  ((v_y - pred_v) ** 2).mean()
test_cost =  ((test_y - pred_test) ** 2).mean()

# %%
train_cost,test_cost,v_cost
# Out:
# (0.0033304102, 0.0031321736, 0.0054545933)

# %%
new_df = pd.DataFrame([['MSE',appliance,train_cost,v_cost,test_cost]])
    
    
results = pd.concat([results,new_df])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9ff1aebfac8c> in <module>()
# ----> 1 new_df = pd.DataFrame([['MSE',appliance,train_cost,v_cost,test_cost]])
#       2
#       3
#       4 results = pd.concat([results,new_df])
#
# NameError: name 'appliance' is not defined

# %%
results_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fe409b43b4a1> in <module>()
# ----> 1 results_df
#
# NameError: name 'results_df' is not defined

# %%
test_input = test_x[-3]
test_truth = test_y[-3]
pred = model.predict(np.array([test_input]))

# %%
np.save('truth_1.txt',test_truth)
np.save('input_1.txt',test_input)
np.save('pred_single_month_input_1.txt',pred[0])

# %%
plt.close('all')
plt.figure(figsize=(20,8))
#plt.plot(np.arange(168*4),test_truth,'r',label="Truth")
plt.plot(np.arange(168*4),np.abs(pred[0] - test_truth)/(.001+test_truth),'g',label='Prediction with a Single Month')
plt.legend()
plt.show()
print (relative_cost(test_truth,pred[0]))
# Out:
# 2.2075098

# %%
X[0]
# Out:
# array([[[2.0885367],
#         [1.7552983],
#         [2.8417618],
#         [1.3944267],
#         [1.7293551],
#         [2.2343967],
#         [1.6603967]],
#
#        [[1.9804666],
#         [1.65768  ],
#         [1.6181266],
#         [1.4750117],
#         [1.4883684],
#         [2.4280133],
#         [2.259585 ]],
#
#        [[1.90035  ],
#         [1.9859867],
#         [1.8725467],
#         [1.4924116],
#         [1.2054284],
#         [1.908915 ],
#         [1.967745 ]],
#
#        [[1.8604566],
#         [1.92769  ],
#         [2.0199618],
#         [1.9734467],
#         [1.661325 ],
#         [2.6458566],
#         [2.06919  ]]], dtype=float32)

# %%
days['/1037']
# Out:
#                      use         air1  clotheswasher1  dishwasher1  \
# date
# 2014-05-01  17245.449219  1536.666626      486.166656     0.000000
# 2014-05-02   7646.549805  1827.783325        0.000000     0.000000
# 2014-05-03   6805.649902  1307.300049        0.000000     0.000000
# 2014-05-04  10498.200195  3248.649902        0.000000   696.250000
# 2014-05-05   8945.150391  2111.949951        0.000000     0.000000
# 2014-05-06  13041.483398  5229.566895        0.000000     0.000000
# 2014-05-07  14346.766602  5812.033203        0.000000     0.000000
# 2014-05-08  15354.400391  6888.483398        0.000000     0.000000
# 2014-05-09  20688.267578  6866.950195      155.233337   725.700012
# 2014-05-10  10485.849609  3860.433350        0.000000     0.000000
# 2014-05-11  18286.117188  8909.483398        0.000000     0.000000
# 2014-05-12  17421.099609  9317.900391        0.000000     0.000000
# 2014-05-13  11708.150391  3938.566650        0.000000     0.000000
# 2014-05-14  15423.716797     0.000000      397.000000   832.400024
# 2014-05-15   6583.300293   531.000000        0.000000     0.000000
# 2014-05-16   6151.466797   512.533325        0.000000     0.000000
# 2014-05-17  11825.549805  2078.616699      159.066666     0.000000
# 2014-05-18   3312.233398   311.833344        0.000000     0.000000
# 2014-05-19  12651.316406  4689.833496        0.000000     0.000000
# 2014-05-20  18310.267578  5534.516602      149.399994   643.400024
# 2014-05-21  14810.083008  6788.466797        0.000000     0.000000
# 2014-05-22  14298.650391  6700.516602        0.000000     0.000000
# 2014-05-23  13737.116211  6773.100098        0.000000     0.000000
# 2014-05-24  19872.300781  5749.100098      264.399994     0.000000
# 2014-05-25  17714.216797  7180.049805        0.000000   820.750000
# 2014-05-26  15195.466797  7256.533203        0.000000     0.000000
# 2014-05-27  15393.833008  3103.983398      150.683334     0.000000
# 2014-05-28   9825.950195  3352.533447        0.000000     0.000000
# 2014-05-29  14541.849609  5857.066895        0.000000   816.099976
# 2014-05-30  15955.433594  7631.100098        0.000000     0.000000
# 2014-05-31  20233.617188  8568.483398      151.300003     0.000000
#
#                   drye1     furnace1  kitchenapp1  microwave1       range1  \
# date
# 2014-05-01  5730.850098   632.933350   284.116669  621.466675   428.866669
# 2014-05-02     0.100000   737.416626   117.716667  167.033325   476.266663
# 2014-05-03     0.100000   499.916656   108.983330  305.433319   752.433350
# 2014-05-04     0.000000  1183.300049   160.266663  109.166664   342.933319
# 2014-05-05     0.050000   873.950012   119.250000   92.483330  1061.449951
# 2014-05-06     0.350000  1960.599976   109.366661  184.350006   490.133362
# 2014-05-07     0.000000  1841.233398   219.616653  195.300003   413.816681
# 2014-05-08     0.000000  2169.966797   217.283325  614.049988   446.799988
# 2014-05-09  4795.416504  2162.933350   249.949997  107.616661   278.533356
# 2014-05-10     0.000000  1286.900024   307.866669  468.783325   271.850006
# 2014-05-11     0.116667  2675.416748   341.233337  292.733337  1075.866699
# 2014-05-12     0.066667  2859.816650   102.550003  154.283340   530.816650
# 2014-05-13     0.000000  1425.016724   203.449997  163.233337   432.916656
# 2014-05-14  5648.266602     1.066667   208.483322  250.216660   535.049988
# 2014-05-15     1.100000   226.666656   448.600006   81.483330   677.383301
# 2014-05-16     0.716667   261.399994   319.733337  279.133331   535.099976
# 2014-05-17  3513.166748   917.000000   188.483337  146.149994   231.633331
# 2014-05-18     0.000000    86.683334    68.133331    4.816667     0.000000
# 2014-05-19     0.433333  1683.466675     0.000000  126.316673  1460.783325
# 2014-05-20  3166.799805  1811.016724   342.100006  328.350006  1150.633301
# 2014-05-21     0.100000  2162.833252   102.599998  430.016663   945.600037
# 2014-05-22     0.000000  2164.899902     0.250000  455.666656   269.766663
# 2014-05-23     0.000000  2162.083252   103.066666  136.100006   474.366669
# 2014-05-24  3497.316650  1884.433350   103.533333  114.966667   819.066650
# 2014-05-25   717.099976  2272.449951   102.916664  191.266663  1214.866699
# 2014-05-26     0.150000  2278.899902   106.283333  264.200012  1125.233398
# 2014-05-27  5154.833496  1090.283325   103.599998  127.533333   413.433350
# 2014-05-28     0.050000  1144.250000   142.516663  167.883331   679.283325
# 2014-05-29     0.050000  1873.116699   192.733322  217.949997   411.000000
# 2014-05-30     0.000000  2361.899902   161.183334   83.466667   935.066711
# 2014-05-31  3564.600098  2584.066650   103.716667   87.116661   453.533325
#
#             refrigerator1  waterheater1
# date
# 2014-05-01     643.500000   3723.383301
# 2014-05-02     903.416687    794.349976
# 2014-05-03     715.700012    785.816650
# 2014-05-04     646.466675   1862.016602
# 2014-05-05     989.783325   1159.650024
# 2014-05-06     803.866699   1455.633301
# 2014-05-07    1158.266724   1770.516724
# 2014-05-08     812.799988    809.599976
# 2014-05-09     749.316650   1705.333374
# 2014-05-10     734.966675   1016.350037
# 2014-05-11     957.283325   1592.466675
# 2014-05-12     723.283325    627.700012
# 2014-05-13     867.616699   1723.683350
# 2014-05-14     636.516663   3823.599854
# 2014-05-15     681.783325   1113.866699
# 2014-05-16     658.083313   1409.033325
# 2014-05-17     859.783325   1409.533325
# 2014-05-18     682.916687    623.833313
# 2014-05-19     815.683350   1742.966675
# 2014-05-20     707.216675   1912.716675
# 2014-05-21     967.983337    794.516663
# 2014-05-22     665.700012   1458.349976
# 2014-05-23     731.666687    637.666626
# 2014-05-24     962.966675   3438.333252
# 2014-05-25     847.166687   1881.933350
# 2014-05-26     744.349976    756.200012
# 2014-05-27     891.700012   1357.483398
# 2014-05-28     729.833313   1185.283325
# 2014-05-29     705.650024   2135.566650
# 2014-05-30    1051.933350   1322.183350
# 2014-05-31     704.383301   1253.966675

# %%
days['/1037']['use']
# Out:
# date
# 2014-07-01    20885.367188
# 2014-07-02    17552.982422
# 2014-07-03    28417.617188
# 2014-07-04    13944.266602
# 2014-07-05    17293.550781
# 2014-07-06    22343.966797
# 2014-07-07    16603.966797
# 2014-07-08    19804.666016
# 2014-07-09    16576.800781
# 2014-07-10    16181.266602
# 2014-07-11    14750.117188
# 2014-07-12    14883.683594
# 2014-07-13    24280.132812
# 2014-07-14    22595.849609
# 2014-07-15    19003.500000
# 2014-07-16    19859.867188
# 2014-07-17    18725.466797
# 2014-07-18    14924.116211
# 2014-07-19    12054.283203
# 2014-07-20    19089.150391
# 2014-07-21    19677.449219
# 2014-07-22    18604.566406
# 2014-07-23    19276.900391
# 2014-07-24    20199.617188
# 2014-07-25    19734.466797
# 2014-07-26    16613.250000
# 2014-07-27    26458.566406
# 2014-07-28    20691.900391
# 2014-07-29    17690.767578
# 2014-07-30    15708.083008
# 2014-07-31    20901.349609
# Name: use, dtype: float32

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png',show_shapes=True)

# %%
model = network()

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')
